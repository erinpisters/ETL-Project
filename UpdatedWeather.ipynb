# %%
import pandas as pd

# %%
# Load in file and read in the CSV
weather_file = "cloudy_updated.csv"
weather_pd = pd.read_csv(weather_file)
weather_pd.head()
# Out:
#    Station        Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  PC_Feb  CD_Feb  \
# 0    13876  BIRMINGHAM ,AL   37      7       6      18      7       6      15
# 1     3856  HUNTSVILLE, AL   27      7       6      18      7       6      16
# 2    13894      MOBILE, AL   47      8       6      17      8       7      14
# 3    13895  MONTGOMERY, AL   51      7       6      17      8       6      14
# 4    26451   ANCHORAGE, AK   44      7       5      19      6       4      18
#
#   CL_Mar    ...      CD_Oct  CL_Nov PC_Nov  CD_Nov  CL_Dec PC_Dec  CD_Dec  \
# 0      7    ...           9      10      7      13       8      7      16
# 1      7    ...          12       9      7      14       8      6      18
# 2      9    ...           9      11      7      12       9      6      16
# 3      8    ...          10      11      6      13       9      6      16
# 4      8    ...          21       6      5      20       6      4      21
#
#    CL_Annual PC_Annual  CD_Annual
# 0         99       111        155
# 1        100       101        164
# 2        102       116        147
# 3        107       107        151
# 4         61        65        239
#
# [5 rows x 42 columns]

# %%
# Using concat to break apart "Location" into 2 columns and splitting by comma
weather_pd=pd.concat([weather_pd,weather_pd.Location.str.split(',',expand=True)],1)
weather_pd.head()
# Out:
#    Station        Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  PC_Feb  CD_Feb  \
# 0    13876  BIRMINGHAM ,AL   37      7       6      18      7       6      15
# 1     3856  HUNTSVILLE, AL   27      7       6      18      7       6      16
# 2    13894      MOBILE, AL   47      8       6      17      8       7      14
# 3    13895  MONTGOMERY, AL   51      7       6      17      8       6      14
# 4    26451   ANCHORAGE, AK   44      7       5      19      6       4      18
#
#   CL_Mar ...   PC_Nov  CD_Nov CL_Dec  PC_Dec  CD_Dec CL_Annual  PC_Annual  \
# 0      7 ...        7      13      8       7      16        99        111
# 1      7 ...        7      14      8       6      18       100        101
# 2      9 ...        7      12      9       6      16       102        116
# 3      8 ...        6      13      9       6      16       107        107
# 4      8 ...        5      20      6       4      21        61         65
#
#    CD_Annual            0    1
# 0        155  BIRMINGHAM    AL
# 1        164   HUNTSVILLE   AL
# 2        147       MOBILE   AL
# 3        151   MONTGOMERY   AL
# 4        239    ANCHORAGE   AK
#
# [5 rows x 44 columns]

# %%
#Renaming new columns
weather_pd = weather_pd.rename(columns={0: "City", 1: "State"})
weather_pd.head()
# Out:
#    Station        Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  PC_Feb  CD_Feb  \
# 0    13876  BIRMINGHAM ,AL   37      7       6      18      7       6      15
# 1     3856  HUNTSVILLE, AL   27      7       6      18      7       6      16
# 2    13894      MOBILE, AL   47      8       6      17      8       7      14
# 3    13895  MONTGOMERY, AL   51      7       6      17      8       6      14
# 4    26451   ANCHORAGE, AK   44      7       5      19      6       4      18
#
#   CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  CD_Dec CL_Annual  PC_Annual  \
# 0      7  ...         7      13      8       7      16        99        111
# 1      7  ...         7      14      8       6      18       100        101
# 2      9  ...         7      12      9       6      16       102        116
# 3      8  ...         6      13      9       6      16       107        107
# 4      8  ...         5      20      6       4      21        61         65
#
#    CD_Annual         City  State
# 0        155  BIRMINGHAM      AL
# 1        164   HUNTSVILLE     AL
# 2        147       MOBILE     AL
# 3        151   MONTGOMERY     AL
# 4        239    ANCHORAGE     AK
#
# [5 rows x 44 columns]

# %%
# Checking the names of all of the columns
weather_pd.columns
# Out:
# Index(['Station', 'Location', 'Year', 'CL_Jan', 'PC_Jan', 'CD_Jan', 'CL_Feb',
#        'PC_Feb', 'CD_Feb', 'CL_Mar', 'PC_Mar', 'CD_Mar', 'CL_Apr', 'PC_Apr',
#        'CD_Apr', 'CL_May', 'PC_May', 'CD_May', 'CL_Jun', 'PC_Jun', 'CD_Jun',
#        'CL_Jul', 'PC_Jul', 'CD_Jul', 'CL_Aug', 'PC_Aug', 'CD_Aug', 'CL_Sep',
#        'PC_Sep', 'CD_Sep', 'CL_Oct', 'PC_Oct', 'CD_Oct', 'CL_Nov', 'PC_Nov',
#        'CD_Nov', 'CL_Dec', 'PC_Dec', 'CD_Dec', 'CL_Annual', 'PC_Annual',
#        'CD_Annual', 'City', 'State'],
#       dtype='object')

# %%
# Checking to see if every column has the same amount of entries
weather_pd.count()
# Out:
# Station      270
# Location     270
# Year         270
# CL_Jan       270
# PC_Jan       270
# CD_Jan       270
# CL_Feb       270
# PC_Feb       270
# CD_Feb       270
# CL_Mar       270
# PC_Mar       270
# CD_Mar       270
# CL_Apr       270
# PC_Apr       270
# CD_Apr       270
# CL_May       270
# PC_May       270
# CD_May       270
# CL_Jun       270
# PC_Jun       270
# CD_Jun       270
# CL_Jul       270
# PC_Jul       270
# CD_Jul       270
# CL_Aug       270
# PC_Aug       270
# CD_Aug       270
# CL_Sep       270
# PC_Sep       270
# CD_Sep       270
# CL_Oct       270
# PC_Oct       270
# CD_Oct       270
# CL_Nov       270
# PC_Nov       270
# CD_Nov       270
# CL_Dec       270
# PC_Dec       270
# CD_Dec       270
# CL_Annual    270
# PC_Annual    270
# CD_Annual    270
# City         270
# State        266
# dtype: int64

# %%
#Dropping rows with missing cells
weather_pd.dropna(inplace = True) 
weather_pd.count()
# Out:
# Station      266
# Location     266
# Year         266
# CL_Jan       266
# PC_Jan       266
# CD_Jan       266
# CL_Feb       266
# PC_Feb       266
# CD_Feb       266
# CL_Mar       266
# PC_Mar       266
# CD_Mar       266
# CL_Apr       266
# PC_Apr       266
# CD_Apr       266
# CL_May       266
# PC_May       266
# CD_May       266
# CL_Jun       266
# PC_Jun       266
# CD_Jun       266
# CL_Jul       266
# PC_Jul       266
# CD_Jul       266
# CL_Aug       266
# PC_Aug       266
# CD_Aug       266
# CL_Sep       266
# PC_Sep       266
# CD_Sep       266
# CL_Oct       266
# PC_Oct       266
# CD_Oct       266
# CL_Nov       266
# PC_Nov       266
# CD_Nov       266
# CL_Dec       266
# PC_Dec       266
# CD_Dec       266
# CL_Annual    266
# PC_Annual    266
# CD_Annual    266
# City         266
# State        266
# dtype: int64

# %%
#Checking to see the column types
weather_pd.dtypes
# Out:
# Station       int64
# Location     object
# Year         object
# CL_Jan       object
# PC_Jan        int64
# CD_Jan        int64
# CL_Feb       object
# PC_Feb        int64
# CD_Feb        int64
# CL_Mar       object
# PC_Mar        int64
# CD_Mar        int64
# CL_Apr       object
# PC_Apr        int64
# CD_Apr        int64
# CL_May       object
# PC_May        int64
# CD_May        int64
# CL_Jun       object
# PC_Jun        int64
# CD_Jun        int64
# CL_Jul       object
# PC_Jul        int64
# CD_Jul        int64
# CL_Aug       object
# PC_Aug        int64
# CD_Aug        int64
# CL_Sep       object
# PC_Sep        int64
# CD_Sep        int64
# CL_Oct       object
# PC_Oct        int64
# CD_Oct        int64
# CL_Nov       object
# PC_Nov        int64
# CD_Nov        int64
# CL_Dec       object
# PC_Dec        int64
# CD_Dec        int64
# CL_Annual     int64
# PC_Annual     int64
# CD_Annual     int64
# City         object
# State        object
# dtype: object

# %%
#Checking to see unique calues in each column
weather_pd.CL_Jan.unique()
# Out:
# array(['7', '8', '4', '6', '15', '14', '2', '9', '5', '11', '10', '12',
#        '13', '3', '1', '*', '0'], dtype=object)

# %%
#Checking to see unique calues in each column
weather_pd.CL_Feb.unique()
# Out:
# array(['7', '8', '6', '3', '12', '10', '5', '2', '4', '9', '11', '13',
#        '15', '14', '*', '1', '0'], dtype=object)

# %%
#Checking to see unique calues in each column
weather_pd.CL_Mar.unique()
# Out:
# array(['7', '9', '8', '4', '14', '2', '10', '6', '12', '11', '3', '5',
#        '15', '13', '17', '1', '*'], dtype=object)

# %%
# Checking to see what rows have * instead of numbers
weather_pd.loc[weather_pd["CL_Jan"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 261    40309                  KOROR, PC          53      *       7      23
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 261      *       7      21      1  ...         8      22      *       7
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 261      24         4         86        273                   KOROR     PC
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [3 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Feb"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 261    40309                  KOROR, PC          53      *       7      23
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 261      *       7      21      1  ...         8      22      *       7
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 261      24         4         86        273                   KOROR     PC
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [3 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Mar"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [2 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Apr"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [2 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_May"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 10     25624                COLD BAY,AK          42      2       5      23
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 10       2       5      22      2  ...         6      23      2       5
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 10       24        10         50        304                COLD BAY     AK
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [3 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Jun"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 10     25624                COLD BAY,AK          42      2       5      23
# 261    40309                  KOROR, PC          53      *       7      23
# 263    40710    MAJURO- MARSHALL IS, PC          49      1       7      23
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
# 268    40308    YAP- W CAROLINE IS., PC          56      1       8      22
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 10       2       5      22      2  ...         6      23      2       5
# 261      *       7      21      1  ...         8      22      *       7
# 263      1       8      19      1  ...         7      23      1       6
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
# 268      0       8      20      1  ...         8      21      0       9
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 10       24        10         50        304                COLD BAY     AK
# 261      24         4         86        273                   KOROR     PC
# 263      24         7         86        271     MAJURO- MARSHALL IS     PC
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
# 268      22         5         90        270     YAP- W CAROLINE IS.     PC
#
# [6 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Jul"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 9      26415               BIG DELTA,AK           3     14       8       9
# 10     25624                COLD BAY,AK          42      2       5      23
# 259    41415                   GUAM, PC          20      3      13      15
# 261    40309                  KOROR, PC          53      *       7      23
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 9        5       7      17      8  ...         6      17      7       7
# 10       2       5      22      2  ...         6      23      2       5
# 259      2      10      16      3  ...        13      15      3      12
# 261      *       7      21      1  ...         8      22      *       7
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 9        17        60         93        212               BIG DELTA     AK
# 10       24        10         50        304                COLD BAY     AK
# 259      16        16        134        215                    GUAM     PC
# 261      24         4         86        273                   KOROR     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [5 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Aug"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 10     25624                COLD BAY,AK          42      2       5      23
# 261    40309                  KOROR, PC          53      *       7      23
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
# 268    40308    YAP- W CAROLINE IS., PC          56      1       8      22
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 10       2       5      22      2  ...         6      23      2       5
# 261      *       7      21      1  ...         8      22      *       7
# 266      *       3      25      *  ...         4      26      *       3
# 268      0       8      20      1  ...         8      21      0       9
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 10       24        10         50        304                COLD BAY     AK
# 261      24         4         86        273                   KOROR     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
# 268      22         5         90        270     YAP- W CAROLINE IS.     PC
#
# [4 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Sep"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 10     25624                COLD BAY,AK          42      2       5      23
# 259    41415                   GUAM, PC          20      3      13      15
# 261    40309                  KOROR, PC          53      *       7      23
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
# 268    40308    YAP- W CAROLINE IS., PC          56      1       8      22
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 10       2       5      22      2  ...         6      23      2       5
# 259      2      10      16      3  ...        13      15      3      12
# 261      *       7      21      1  ...         8      22      *       7
# 266      *       3      25      *  ...         4      26      *       3
# 268      0       8      20      1  ...         8      21      0       9
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 10       24        10         50        304                COLD BAY     AK
# 259      16        16        134        215                    GUAM     PC
# 261      24         4         86        273                   KOROR     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
# 268      22         5         90        270     YAP- W CAROLINE IS.     PC
#
# [5 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Oct"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 259    41415                   GUAM, PC          20      3      13      15
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 259      2      10      16      3  ...        13      15      3      12
# 266      *       3      25      *  ...         4      26      *       3
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 259      16        16        134        215                    GUAM     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [2 rows x 44 columns]

# %%
weather_pd.loc[weather_pd["CL_Nov"]=="*"]
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 261    40309                  KOROR, PC          53      *       7      23
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
# 268    40308    YAP- W CAROLINE IS., PC          56      1       8      22
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 261      *       7      21      1  ...         8      22      *       7
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
# 268      0       8      20      1  ...         8      21      0       9
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                    City  State
# 261      24         4         86        273                   KOROR     PC
# 265      26         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318  CHUUK- E. CAROLINE IS.      P
# 268      22         5         90        270     YAP- W CAROLINE IS.     PC
#
# [4 rows x 44 columns]

# %%
weather_pd["CL_Dec"].dtype
# Out:
# dtype('O')

# %%
weather_pd.head(269)
# Out:
#      Station                   Location        Year CL_Jan  PC_Jan  CD_Jan  \
# 0      13876             BIRMINGHAM ,AL          37      7       6      18
# 1       3856             HUNTSVILLE, AL          27      7       6      18
# 2      13894                 MOBILE, AL          47      8       6      17
# 3      13895             MONTGOMERY, AL          51      7       6      17
# 4      26451              ANCHORAGE, AK          44      7       5      19
# 5      25308                ANNETTE, AK          41      4       4      23
# 6      27502                 BARROW, AK          54      6       2       3
# 7      26615                 BETHEL, AK          34      8       5      18
# 8      26533                 BETTLES,AK           5     15       5      11
# 9      26415               BIG DELTA,AK           3     14       8       9
# 10     25624                COLD BAY,AK          42      2       5      23
# 11     26411              FAIRBANKS, AK          45      9       6      16
# 12     26425                 GULKANA,AK           5     15       4      12
# 13     25507                  HOMER, AK          15      8       4      19
# 14     25309                 JUNEAU, AK          47      6       3      23
# 15     25503            KING SALMON, AK          42      8       5      18
# 16     25501                 KODIAK, AK          25      5       6      20
# 17     26616               KOTZEBUE, AK          52     11       4      16
# 18     26510                MCGRATH, AK          55      9       5      17
# 19     26617                   NOME, AK          51     10       4      17
# 20     25713        ST. PAUL ISLAND, AK          66      2       6      23
# 21     26528              TALKEETNA, AK          10      6       4      21
# 22     26627             UNALAKLEET, AK           4      8       4      20
# 23     26442                 VALDEZ, AK          26      5       4      21
# 24     25339                YAKUTAT, AK          48      5       3      22
# 25      3103              FLAGSTAFF, AZ          43     12       6      12
# 26     23183                PHOENIX, AZ          57     14       7      10
# 27     23160                 TUCSON, AZ          55     14       7      10
# 28     23194                WINSLOW, AZ          37     12       7      12
# 29     23195                   YUMA, AZ          32     15       7       9
# ..       ...                        ...         ...    ...     ...     ...
# 240    13741                ROANOKE, VA          48      8       8      15
# 241    24227                OLYMPIA, WA          54      2       4      25
# 242    94240             QUILLAYUTE, WA          29      3       3      24
# 243    24281           SEATTLE C.O., WA          24      3       5      23
# 244    24233     SEATTLE SEA-TAC AP, WA          51      3       4      24
# 245    24157                SPOKANE, WA          48      3       4      24
# 246    24243                 YAKIMA, WA          49      4       5      22
# 247     3872                BECKLEY, WV          32      5       5      21
# 248    13866             CHARLESTON, WV          47      4       6      21
# 249    13729                 ELKINS, WV          49      3       6      22
# 250     3860             HUNTINGTON, WV          34      4       6      21
# 251    14898              GREEN BAY, WI          46      8       7      17
# 252    14920              LA CROSSE, WI          17      7       7      17
# 253    14837                MADISON, WI          49      7       6      17
# 254    14839              MILWAUKEE, WI          55      7       6      18
# 255    24089                 CASPER, WY          45      7       8      16
# 256    24018               CHEYENNE, WY          60      9      10      13
# 257    24021                 LANDER, WY          49      8      10      13
# 258    24029               SHERIDAN, WY          55      6       8      17
# 259    41415                   GUAM, PC          20      3      13      15
# 260    21603        JOHNSTON ISLAND, PC          24     13      14       4
# 261    40309                  KOROR, PC          53      *       7      23
# 262    40604   KWAJALEIN- MARSHALL IS.,  PC      44      2       7      21
# 263    40710    MAJURO- MARSHALL IS, PC          49      1       7      23
# 264    61705  PAGO PAGO- AMER SAMOA, PC          39      0      10      21
# 265    40504  POHNPEI- CAROLINE IS., PC          53      *       4      26
# 266    40505  CHUUK- E. CAROLINE IS., P  C       54      *       4      27
# 267    41606            WAKE ISLAND, PC          43     12      13       5
# 268    40308    YAP- W CAROLINE IS., PC          56      1       8      22
# 269    11641               SAN JUAN, PR          40      9      18       4
#
#     CL_Feb  PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  \
# 0        7       6      15      7  ...         7      13      8       7
# 1        7       6      16      7  ...         7      14      8       6
# 2        8       7      14      9  ...         7      12      9       6
# 3        8       6      14      8  ...         6      13      9       6
# 4        6       4      18      8  ...         5      20      6       4
# 5        3       4      21      4  ...         3      24      3       4
# 6       12       6      11     14  ...         3      11      4       0
# 7       10       4      14      9  ...         5      19      8       5
# 8       10       4      14      9  ...         6      14      9       7
# 9        5       7      17      8  ...         6      17      7       7
# 10       2       5      22      2  ...         6      23      2       5
# 11       8       6      14     10  ...         5      18      7       6
# 12       6       4      18      9  ...         5      21      7       7
# 13       7       4      17      6  ...         5      19      7       5
# 14       4       3      21      4  ...         2      24      3       2
# 15       7       5      16      8  ...         5      19      7       6
# 16       6       5      18      6  ...         7      16      6       6
# 17      12       3      13     12  ...         4      17     11       4
# 18       9       4      15      9  ...         4      19      8       5
# 19      12       4      13     11  ...         4      18     10       4
# 20       3       6      20      3  ...         6      22      1       5
# 21       8       4      16      9  ...         3      19      5       2
# 22      10       3      15     10  ...         5      18     11       4
# 23       5       3      20      8  ...         4      20      5       3
# 24       4       3      21      5  ...         3      23      4       3
# 25      11       6      11     12  ...         7       8     14       6
# 26      13       7       9     14  ...         6       6     15       6
# 27      13       7       9     15  ...         6       6     15       6
# 28      12       7      10     13  ...         6       8     14       7
# 29      15       7       6     17  ...         6       5     17       7
# ..     ...     ...     ...    ...  ...       ...     ...    ...     ...
# 240      8       7      14      8  ...         8      13      9       8
# 241      2       4      22      3  ...         5      23      2       4
# 242      4       4      21      4  ...         5      22      4       4
# 243      3       6      19      4  ...         6      21      3       5
# 244      3       4      21      3  ...         4      23      2       4
# 245      3       5      20      5  ...         5      22      3       4
# 246      4       6      18      6  ...         6      19      4       5
# 247      4       5      18      5  ...         7      18      5       6
# 248      4       6      18      5  ...         7      18      5       6
# 249      3       6      19      4  ...         6      19      4       5
# 250      4       5      19      5  ...         6      19      5       5
# 251      7       7      15      7  ...         6      19      6       6
# 252      8       7      13      7  ...         6      18      7       6
# 253      7       6      15      6  ...         6      18      6       6
# 254      6       6      15      6  ...         6      18      6       6
# 255      6       8      14      6  ...         8      14      8       8
# 256      7       9      12      7  ...         9      11      9       9
# 257      7      10      12      7  ...        10      12     10      10
# 258      5       8      15      5  ...         8      16      7       8
# 259      2      10      16      3  ...        13      15      3      12
# 260     11      13       4     11  ...        12      12     11      13
# 261      *       7      21      1  ...         8      22      *       7
# 262      2       6      20      2  ...         6      23      2       6
# 263      1       8      19      1  ...         7      23      1       6
# 264      0       9      18      1  ...        11      18      1      10
# 265      *       4      24      *  ...         6      24      *       5
# 266      *       3      25      *  ...         4      26      *       3
# 267     12      11       5     12  ...        13       5     14      13
# 268      0       8      20      1  ...         8      21      0       9
# 269      7      16       4      9  ...        18       7      7      18
#
#      CD_Dec CL_Annual  PC_Annual  CD_Annual                     City  State
# 0        16        99        111        155              BIRMINGHAM      AL
# 1        18       100        101        164               HUNTSVILLE     AL
# 2        16       102        116        147                   MOBILE     AL
# 3        16       107        107        151               MONTGOMERY     AL
# 4        21        61         65        239                ANCHORAGE     AK
# 5        24        40         60        265                  ANNETTE     AK
# 6         0        66         52        187                   BARROW     AK
# 7        18        62         65        239                   BETHEL     AK
# 8        15        86         93        187                  BETTLES     AK
# 9        17        60         93        212                BIG DELTA     AK
# 10       24        10         50        304                 COLD BAY     AK
# 11       18        70         86        210                FAIRBANKS     AK
# 12       17        67         89        209                  GULKANA     AK
# 13       18        65         75        225                    HOMER     AK
# 14       25        44         41        280                   JUNEAU     AK
# 15       19        51         69        245              KING SALMON     AK
# 16       19        59         74        232                   KODIAK     AK
# 17       16       100         72        193                 KOTZEBUE     AK
# 18       19        67         72        226                  MCGRATH     AK
# 19       17        91         69        205                     NOME     AK
# 20       24        18         61        287          ST. PAUL ISLAND     AK
# 21       22        67         67        225                TALKEETNA     AK
# 22       16        83         67        215               UNALAKLEET     AK
# 23       23        57         57        251                   VALDEZ     AK
# 24       24        41         46        278                  YAKUTAT     AK
# 25       11       162        102        102                FLAGSTAFF     AZ
# 26        9       211         85         70                  PHOENIX     AZ
# 27       10       193         91         81                   TUCSON     AZ
# 28       10       177         99         89                  WINSLOW     AZ
# 29        8       242         71         52                     YUMA     AZ
# ..      ...       ...        ...        ...                      ...    ...
# 240      14       102        112        151                  ROANOKE     VA
# 241      26        52         84        228                  OLYMPIA     WA
# 242      24        51         75        239               QUILLAYUTE     WA
# 243      23        71         93        201             SEATTLE C.O.     WA
# 244      25        58         82        226       SEATTLE SEA-TAC AP     WA
# 245      24        86         88        191                  SPOKANE     WA
# 246      22       109         92        164                   YAKIMA     WA
# 247      21        60         95        210                  BECKLEY     WV
# 248      20        65        111        189               CHARLESTON     WV
# 249      21        48        103        212                   ELKINS     WV
# 250      21        63         99        203               HUNTINGTON     WV
# 251      19        85        102        178                GREEN BAY     WI
# 252      18        95         97        173                LA CROSSE     WI
# 253      19        89         96        180                  MADISON     WI
# 254      19        90        100        175                MILWAUKEE     WI
# 255      15       107        111        147                   CASPER     WY
# 256      13       106        127        133                 CHEYENNE     WY
# 257      12       114        122        129                   LANDER     WY
# 258      17        95        113        157                 SHERIDAN     WY
# 259      16        16        134        215                     GUAM     PC
# 260       7        99        159        107          JOHNSTON ISLAND     PC
# 261      24         4         86        273                    KOROR     PC
# 262      23        17         76        272  KWAJALEIN- MARSHALL IS.
# 263      24         7         86        271      MAJURO- MARSHALL IS     PC
# 264      20        12        151        202    PAGO PAGO- AMER SAMOA     PC
# 265      26         2         64        298    POHNPEI- CAROLINE IS.     PC
# 266      28         0         45        318   CHUUK- E. CAROLINE IS.      P
# 267       4       121        149         94              WAKE ISLAND     PC
# 268      22         5         90        270      YAP- W CAROLINE IS.     PC
# 269       6        73        203         89                 SAN JUAN     PR
#
# [266 rows x 44 columns]

# %%
weather_pd.drop([9,10,258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269], inplace=True)

# %%
weather_pd.head(256)
# Out:
#      Station                Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  \
# 0      13876          BIRMINGHAM ,AL   37      7       6      18      7
# 1       3856          HUNTSVILLE, AL   27      7       6      18      7
# 2      13894              MOBILE, AL   47      8       6      17      8
# 3      13895          MONTGOMERY, AL   51      7       6      17      8
# 4      26451           ANCHORAGE, AK   44      7       5      19      6
# 5      25308             ANNETTE, AK   41      4       4      23      3
# 6      27502              BARROW, AK   54      6       2       3     12
# 7      26615              BETHEL, AK   34      8       5      18     10
# 8      26533              BETTLES,AK    5     15       5      11     10
# 11     26411           FAIRBANKS, AK   45      9       6      16      8
# 12     26425              GULKANA,AK    5     15       4      12      6
# 13     25507               HOMER, AK   15      8       4      19      7
# 14     25309              JUNEAU, AK   47      6       3      23      4
# 15     25503         KING SALMON, AK   42      8       5      18      7
# 16     25501              KODIAK, AK   25      5       6      20      6
# 17     26616            KOTZEBUE, AK   52     11       4      16     12
# 18     26510             MCGRATH, AK   55      9       5      17      9
# 19     26617                NOME, AK   51     10       4      17     12
# 20     25713     ST. PAUL ISLAND, AK   66      2       6      23      3
# 21     26528           TALKEETNA, AK   10      6       4      21      8
# 22     26627          UNALAKLEET, AK    4      8       4      20     10
# 23     26442              VALDEZ, AK   26      5       4      21      5
# 24     25339             YAKUTAT, AK   48      5       3      22      4
# 25      3103           FLAGSTAFF, AZ   43     12       6      12     11
# 26     23183             PHOENIX, AZ   57     14       7      10     13
# 27     23160              TUCSON, AZ   55     14       7      10     13
# 28     23194             WINSLOW, AZ   37     12       7      12     12
# 29     23195                YUMA, AZ   32     15       7       9     15
# 30     13964          FORT SMITH, AR   49      9       6      16      9
# 31     13963         LITTLE ROCK, AR   35      9       6      16      9
# ..       ...                     ...  ...    ...     ...     ...    ...
# 228    12917         PORT ARTHUR, TX   42      7       6      18      8
# 229    23034          SAN ANGELO, TX   47     12       6      13     11
# 230    12921         SAN ANTONIO, TX   53      9       6      16      8
# 231    12912            VICTORIA, TX   34      7       6      18      7
# 232    13959                WACO, TX   50      9       6      16      9
# 233    13966       WICHITA FALLS, TX   50     11       6      14     10
# 234    23176             MILFORD, UT   40      9       8      14      8
# 235    24127      SALT LAKE CITY, UT   69      6       6      19      5
# 236    14742          BURLINGTON, VT   52      5       6      20      4
# 237    13733           LYNCHBURG, VA   49      9       7      15      8
# 238    13737             NORFOLK, VA   47      9       7      16      8
# 239    13740            RICHMOND, VA   50      8       7      16      8
# 240    13741             ROANOKE, VA   48      8       8      15      8
# 241    24227             OLYMPIA, WA   54      2       4      25      2
# 242    94240          QUILLAYUTE, WA   29      3       3      24      4
# 243    24281        SEATTLE C.O., WA   24      3       5      23      3
# 244    24233  SEATTLE SEA-TAC AP, WA   51      3       4      24      3
# 245    24157             SPOKANE, WA   48      3       4      24      3
# 246    24243              YAKIMA, WA   49      4       5      22      4
# 247     3872             BECKLEY, WV   32      5       5      21      4
# 248    13866          CHARLESTON, WV   47      4       6      21      4
# 249    13729              ELKINS, WV   49      3       6      22      3
# 250     3860          HUNTINGTON, WV   34      4       6      21      4
# 251    14898           GREEN BAY, WI   46      8       7      17      7
# 252    14920           LA CROSSE, WI   17      7       7      17      8
# 253    14837             MADISON, WI   49      7       6      17      7
# 254    14839           MILWAUKEE, WI   55      7       6      18      6
# 255    24089              CASPER, WY   45      7       8      16      6
# 256    24018            CHEYENNE, WY   60      9      10      13      7
# 257    24021              LANDER, WY   49      8      10      13      7
#
#      PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  CD_Dec  \
# 0         6      15      7  ...         7      13      8       7      16
# 1         6      16      7  ...         7      14      8       6      18
# 2         7      14      9  ...         7      12      9       6      16
# 3         6      14      8  ...         6      13      9       6      16
# 4         4      18      8  ...         5      20      6       4      21
# 5         4      21      4  ...         3      24      3       4      24
# 6         6      11     14  ...         3      11      4       0       0
# 7         4      14      9  ...         5      19      8       5      18
# 8         4      14      9  ...         6      14      9       7      15
# 11        6      14     10  ...         5      18      7       6      18
# 12        4      18      9  ...         5      21      7       7      17
# 13        4      17      6  ...         5      19      7       5      18
# 14        3      21      4  ...         2      24      3       2      25
# 15        5      16      8  ...         5      19      7       6      19
# 16        5      18      6  ...         7      16      6       6      19
# 17        3      13     12  ...         4      17     11       4      16
# 18        4      15      9  ...         4      19      8       5      19
# 19        4      13     11  ...         4      18     10       4      17
# 20        6      20      3  ...         6      22      1       5      24
# 21        4      16      9  ...         3      19      5       2      22
# 22        3      15     10  ...         5      18     11       4      16
# 23        3      20      8  ...         4      20      5       3      23
# 24        3      21      5  ...         3      23      4       3      24
# 25        6      11     12  ...         7       8     14       6      11
# 26        7       9     14  ...         6       6     15       6       9
# 27        7       9     15  ...         6       6     15       6      10
# 28        7      10     13  ...         6       8     14       7      10
# 29        7       6     17  ...         6       5     17       7       8
# 30        6      14      9  ...         6      13     10       7      15
# 31        6      13      9  ...         6      13      9       6      16
# ..      ...     ...    ...  ...       ...     ...    ...     ...     ...
# 228       6      15      7  ...         7      13      8       6      17
# 229       6      11     12  ...         6      10     12       7      12
# 230       6      14      9  ...         7      13     10       6      16
# 231       6      16      7  ...         7      14      7       6      19
# 232       6      14     10  ...         6      12     11       6      15
# 233       6      12     11  ...         6      11     12       6      13
# 234       8      12      9  ...         8      11     10       8      13
# 235       7      16      7  ...         7      15      6       6      18
# 236       7      17      6  ...         5      22      3       6      22
# 237       7      13      9  ...         7      13     10       7      14
# 238       6      14      9  ...         8      12      9       7      15
# 239       6      14      8  ...         8      13      9       6      15
# 240       7      14      8  ...         8      13      9       8      14
# 241       4      22      3  ...         5      23      2       4      26
# 242       4      21      4  ...         5      22      4       4      24
# 243       6      19      4  ...         6      21      3       5      23
# 244       4      21      3  ...         4      23      2       4      25
# 245       5      20      5  ...         5      22      3       4      24
# 246       6      18      6  ...         6      19      4       5      22
# 247       5      18      5  ...         7      18      5       6      21
# 248       6      18      5  ...         7      18      5       6      20
# 249       6      19      4  ...         6      19      4       5      21
# 250       5      19      5  ...         6      19      5       5      21
# 251       7      15      7  ...         6      19      6       6      19
# 252       7      13      7  ...         6      18      7       6      18
# 253       6      15      6  ...         6      18      6       6      19
# 254       6      15      6  ...         6      18      6       6      19
# 255       8      14      6  ...         8      14      8       8      15
# 256       9      12      7  ...         9      11      9       9      13
# 257      10      12      7  ...        10      12     10      10      12
#
#     CL_Annual  PC_Annual  CD_Annual                City  State
# 0          99        111        155         BIRMINGHAM      AL
# 1         100        101        164          HUNTSVILLE     AL
# 2         102        116        147              MOBILE     AL
# 3         107        107        151          MONTGOMERY     AL
# 4          61         65        239           ANCHORAGE     AK
# 5          40         60        265             ANNETTE     AK
# 6          66         52        187              BARROW     AK
# 7          62         65        239              BETHEL     AK
# 8          86         93        187             BETTLES     AK
# 11         70         86        210           FAIRBANKS     AK
# 12         67         89        209             GULKANA     AK
# 13         65         75        225               HOMER     AK
# 14         44         41        280              JUNEAU     AK
# 15         51         69        245         KING SALMON     AK
# 16         59         74        232              KODIAK     AK
# 17        100         72        193            KOTZEBUE     AK
# 18         67         72        226             MCGRATH     AK
# 19         91         69        205                NOME     AK
# 20         18         61        287     ST. PAUL ISLAND     AK
# 21         67         67        225           TALKEETNA     AK
# 22         83         67        215          UNALAKLEET     AK
# 23         57         57        251              VALDEZ     AK
# 24         41         46        278             YAKUTAT     AK
# 25        162        102        102           FLAGSTAFF     AZ
# 26        211         85         70             PHOENIX     AZ
# 27        193         91         81              TUCSON     AZ
# 28        177         99         89             WINSLOW     AZ
# 29        242         71         52                YUMA     AZ
# 30        123         95        147          FORT SMITH     AR
# 31        119        100        147         LITTLE ROCK     AR
# ..        ...        ...        ...                 ...    ...
# 228        95        117        153         PORT ARTHUR     TX
# 229       154         97        114          SAN ANGELO     TX
# 230       105        119        141         SAN ANTONIO     TX
# 231        86        118        162            VICTORIA     TX
# 232       130         98        136                WACO     TX
# 233       151         93        120       WICHITA FALLS     TX
# 234       151        104        111             MILFORD     UT
# 235       125        101        139      SALT LAKE CITY     UT
# 236        58        101        206          BURLINGTON     VT
# 237       112        107        147           LYNCHBURG     VA
# 238       106        107        153             NORFOLK     VA
# 239       100        106        160            RICHMOND     VA
# 240       102        112        151             ROANOKE     VA
# 241        52         84        228             OLYMPIA     WA
# 242        51         75        239          QUILLAYUTE     WA
# 243        71         93        201        SEATTLE C.O.     WA
# 244        58         82        226  SEATTLE SEA-TAC AP     WA
# 245        86         88        191             SPOKANE     WA
# 246       109         92        164              YAKIMA     WA
# 247        60         95        210             BECKLEY     WV
# 248        65        111        189          CHARLESTON     WV
# 249        48        103        212              ELKINS     WV
# 250        63         99        203          HUNTINGTON     WV
# 251        85        102        178           GREEN BAY     WI
# 252        95         97        173           LA CROSSE     WI
# 253        89         96        180             MADISON     WI
# 254        90        100        175           MILWAUKEE     WI
# 255       107        111        147              CASPER     WY
# 256       106        127        133            CHEYENNE     WY
# 257       114        122        129              LANDER     WY
#
# [252 rows x 44 columns]

# %%
weather_pd["CL_Annual_Check"] = pd.to_numeric(weather_pd["CL_Jan"]) + pd.to_numeric(weather_pd["CL_Feb"]) + pd.to_numeric(weather_pd["CL_Mar"]) + pd.to_numeric(weather_pd["CL_Apr"]) + pd.to_numeric(weather_pd["CL_May"]) + pd.to_numeric(weather_pd["CL_Jun"]) + pd.to_numeric(weather_pd["CL_Jul"]) + pd.to_numeric(weather_pd["CL_Aug"]) + pd.to_numeric(weather_pd["CL_Sep"]) + pd.to_numeric(weather_pd["CL_Oct"]) + pd.to_numeric(weather_pd["CL_Nov"]) + pd.to_numeric(weather_pd["CL_Dec"])
weather_pd.head(256)
# Out:
#      Station                Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  \
# 0      13876          BIRMINGHAM ,AL   37      7       6      18      7
# 1       3856          HUNTSVILLE, AL   27      7       6      18      7
# 2      13894              MOBILE, AL   47      8       6      17      8
# 3      13895          MONTGOMERY, AL   51      7       6      17      8
# 4      26451           ANCHORAGE, AK   44      7       5      19      6
# 5      25308             ANNETTE, AK   41      4       4      23      3
# 6      27502              BARROW, AK   54      6       2       3     12
# 7      26615              BETHEL, AK   34      8       5      18     10
# 8      26533              BETTLES,AK    5     15       5      11     10
# 11     26411           FAIRBANKS, AK   45      9       6      16      8
# 12     26425              GULKANA,AK    5     15       4      12      6
# 13     25507               HOMER, AK   15      8       4      19      7
# 14     25309              JUNEAU, AK   47      6       3      23      4
# 15     25503         KING SALMON, AK   42      8       5      18      7
# 16     25501              KODIAK, AK   25      5       6      20      6
# 17     26616            KOTZEBUE, AK   52     11       4      16     12
# 18     26510             MCGRATH, AK   55      9       5      17      9
# 19     26617                NOME, AK   51     10       4      17     12
# 20     25713     ST. PAUL ISLAND, AK   66      2       6      23      3
# 21     26528           TALKEETNA, AK   10      6       4      21      8
# 22     26627          UNALAKLEET, AK    4      8       4      20     10
# 23     26442              VALDEZ, AK   26      5       4      21      5
# 24     25339             YAKUTAT, AK   48      5       3      22      4
# 25      3103           FLAGSTAFF, AZ   43     12       6      12     11
# 26     23183             PHOENIX, AZ   57     14       7      10     13
# 27     23160              TUCSON, AZ   55     14       7      10     13
# 28     23194             WINSLOW, AZ   37     12       7      12     12
# 29     23195                YUMA, AZ   32     15       7       9     15
# 30     13964          FORT SMITH, AR   49      9       6      16      9
# 31     13963         LITTLE ROCK, AR   35      9       6      16      9
# ..       ...                     ...  ...    ...     ...     ...    ...
# 228    12917         PORT ARTHUR, TX   42      7       6      18      8
# 229    23034          SAN ANGELO, TX   47     12       6      13     11
# 230    12921         SAN ANTONIO, TX   53      9       6      16      8
# 231    12912            VICTORIA, TX   34      7       6      18      7
# 232    13959                WACO, TX   50      9       6      16      9
# 233    13966       WICHITA FALLS, TX   50     11       6      14     10
# 234    23176             MILFORD, UT   40      9       8      14      8
# 235    24127      SALT LAKE CITY, UT   69      6       6      19      5
# 236    14742          BURLINGTON, VT   52      5       6      20      4
# 237    13733           LYNCHBURG, VA   49      9       7      15      8
# 238    13737             NORFOLK, VA   47      9       7      16      8
# 239    13740            RICHMOND, VA   50      8       7      16      8
# 240    13741             ROANOKE, VA   48      8       8      15      8
# 241    24227             OLYMPIA, WA   54      2       4      25      2
# 242    94240          QUILLAYUTE, WA   29      3       3      24      4
# 243    24281        SEATTLE C.O., WA   24      3       5      23      3
# 244    24233  SEATTLE SEA-TAC AP, WA   51      3       4      24      3
# 245    24157             SPOKANE, WA   48      3       4      24      3
# 246    24243              YAKIMA, WA   49      4       5      22      4
# 247     3872             BECKLEY, WV   32      5       5      21      4
# 248    13866          CHARLESTON, WV   47      4       6      21      4
# 249    13729              ELKINS, WV   49      3       6      22      3
# 250     3860          HUNTINGTON, WV   34      4       6      21      4
# 251    14898           GREEN BAY, WI   46      8       7      17      7
# 252    14920           LA CROSSE, WI   17      7       7      17      8
# 253    14837             MADISON, WI   49      7       6      17      7
# 254    14839           MILWAUKEE, WI   55      7       6      18      6
# 255    24089              CASPER, WY   45      7       8      16      6
# 256    24018            CHEYENNE, WY   60      9      10      13      7
# 257    24021              LANDER, WY   49      8      10      13      7
#
#      PC_Feb  CD_Feb CL_Mar       ...         CD_Nov  CL_Dec PC_Dec  CD_Dec  \
# 0         6      15      7       ...             13       8      7      16
# 1         6      16      7       ...             14       8      6      18
# 2         7      14      9       ...             12       9      6      16
# 3         6      14      8       ...             13       9      6      16
# 4         4      18      8       ...             20       6      4      21
# 5         4      21      4       ...             24       3      4      24
# 6         6      11     14       ...             11       4      0       0
# 7         4      14      9       ...             19       8      5      18
# 8         4      14      9       ...             14       9      7      15
# 11        6      14     10       ...             18       7      6      18
# 12        4      18      9       ...             21       7      7      17
# 13        4      17      6       ...             19       7      5      18
# 14        3      21      4       ...             24       3      2      25
# 15        5      16      8       ...             19       7      6      19
# 16        5      18      6       ...             16       6      6      19
# 17        3      13     12       ...             17      11      4      16
# 18        4      15      9       ...             19       8      5      19
# 19        4      13     11       ...             18      10      4      17
# 20        6      20      3       ...             22       1      5      24
# 21        4      16      9       ...             19       5      2      22
# 22        3      15     10       ...             18      11      4      16
# 23        3      20      8       ...             20       5      3      23
# 24        3      21      5       ...             23       4      3      24
# 25        6      11     12       ...              8      14      6      11
# 26        7       9     14       ...              6      15      6       9
# 27        7       9     15       ...              6      15      6      10
# 28        7      10     13       ...              8      14      7      10
# 29        7       6     17       ...              5      17      7       8
# 30        6      14      9       ...             13      10      7      15
# 31        6      13      9       ...             13       9      6      16
# ..      ...     ...    ...       ...            ...     ...    ...     ...
# 228       6      15      7       ...             13       8      6      17
# 229       6      11     12       ...             10      12      7      12
# 230       6      14      9       ...             13      10      6      16
# 231       6      16      7       ...             14       7      6      19
# 232       6      14     10       ...             12      11      6      15
# 233       6      12     11       ...             11      12      6      13
# 234       8      12      9       ...             11      10      8      13
# 235       7      16      7       ...             15       6      6      18
# 236       7      17      6       ...             22       3      6      22
# 237       7      13      9       ...             13      10      7      14
# 238       6      14      9       ...             12       9      7      15
# 239       6      14      8       ...             13       9      6      15
# 240       7      14      8       ...             13       9      8      14
# 241       4      22      3       ...             23       2      4      26
# 242       4      21      4       ...             22       4      4      24
# 243       6      19      4       ...             21       3      5      23
# 244       4      21      3       ...             23       2      4      25
# 245       5      20      5       ...             22       3      4      24
# 246       6      18      6       ...             19       4      5      22
# 247       5      18      5       ...             18       5      6      21
# 248       6      18      5       ...             18       5      6      20
# 249       6      19      4       ...             19       4      5      21
# 250       5      19      5       ...             19       5      5      21
# 251       7      15      7       ...             19       6      6      19
# 252       7      13      7       ...             18       7      6      18
# 253       6      15      6       ...             18       6      6      19
# 254       6      15      6       ...             18       6      6      19
# 255       8      14      6       ...             14       8      8      15
# 256       9      12      7       ...             11       9      9      13
# 257      10      12      7       ...             12      10     10      12
#
#      CL_Annual PC_Annual  CD_Annual                City State  CL_Annual_Check
# 0           99       111        155         BIRMINGHAM     AL               98
# 1          100       101        164          HUNTSVILLE    AL              100
# 2          102       116        147              MOBILE    AL              103
# 3          107       107        151          MONTGOMERY    AL              108
# 4           61        65        239           ANCHORAGE    AK               61
# 5           40        60        265             ANNETTE    AK               40
# 6           66        52        187              BARROW    AK               66
# 7           62        65        239              BETHEL    AK               63
# 8           86        93        187             BETTLES    AK               86
# 11          70        86        210           FAIRBANKS    AK               70
# 12          67        89        209             GULKANA    AK               68
# 13          65        75        225               HOMER    AK               65
# 14          44        41        280              JUNEAU    AK               44
# 15          51        69        245         KING SALMON    AK               52
# 16          59        74        232              KODIAK    AK               57
# 17         100        72        193            KOTZEBUE    AK              101
# 18          67        72        226             MCGRATH    AK               65
# 19          91        69        205                NOME    AK               91
# 20          18        61        287     ST. PAUL ISLAND    AK               18
# 21          67        67        225           TALKEETNA    AK               66
# 22          83        67        215          UNALAKLEET    AK               84
# 23          57        57        251              VALDEZ    AK               57
# 24          41        46        278             YAKUTAT    AK               41
# 25         162       102        102           FLAGSTAFF    AZ              161
# 26         211        85         70             PHOENIX    AZ              212
# 27         193        91         81              TUCSON    AZ              194
# 28         177        99         89             WINSLOW    AZ              179
# 29         242        71         52                YUMA    AZ              242
# 30         123        95        147          FORT SMITH    AR              125
# 31         119       100        147         LITTLE ROCK    AR              119
# ..         ...       ...        ...                 ...   ...              ...
# 228         95       117        153         PORT ARTHUR    TX               96
# 229        154        97        114          SAN ANGELO    TX              155
# 230        105       119        141         SAN ANTONIO    TX              105
# 231         86       118        162            VICTORIA    TX               86
# 232        130        98        136                WACO    TX              131
# 233        151        93        120       WICHITA FALLS    TX              152
# 234        151       104        111             MILFORD    UT              152
# 235        125       101        139      SALT LAKE CITY    UT              125
# 236         58       101        206          BURLINGTON    VT               59
# 237        112       107        147           LYNCHBURG    VA              111
# 238        106       107        153             NORFOLK    VA              105
# 239        100       106        160            RICHMOND    VA               99
# 240        102       112        151             ROANOKE    VA              103
# 241         52        84        228             OLYMPIA    WA               53
# 242         51        75        239          QUILLAYUTE    WA               53
# 243         71        93        201        SEATTLE C.O.    WA               71
# 244         58        82        226  SEATTLE SEA-TAC AP    WA               56
# 245         86        88        191             SPOKANE    WA               85
# 246        109        92        164              YAKIMA    WA              108
# 247         60        95        210             BECKLEY    WV               59
# 248         65       111        189          CHARLESTON    WV               66
# 249         48       103        212              ELKINS    WV               46
# 250         63        99        203          HUNTINGTON    WV               65
# 251         85       102        178           GREEN BAY    WI               85
# 252         95        97        173           LA CROSSE    WI               95
# 253         89        96        180             MADISON    WI               87
# 254         90       100        175           MILWAUKEE    WI               89
# 255        107       111        147              CASPER    WY              106
# 256        106       127        133            CHEYENNE    WY              108
# 257        114       122        129              LANDER    WY              115
#
# [252 rows x 45 columns]

# %%
#Checking to see whether two columns are equal - since theyre not equal, will go ahead and use CL_annual number
weather_pd['CL_Annual_Check'].equals(weather_pd['CL_Annual'])
# Out:
# False

# %%
#Only using columns that we need
weather_updated = weather_pd[["City", "State", "Station", "CL_Annual"]]
weather_updated.head()
# Out:
#           City State  Station  CL_Annual
# 0  BIRMINGHAM     AL    13876         99
# 1   HUNTSVILLE    AL     3856        100
# 2       MOBILE    AL    13894        102
# 3   MONTGOMERY    AL    13895        107
# 4    ANCHORAGE    AK    26451         61

# %%
# Merging on Inner
#print pd.merge(weather_updated, crime_final, on='City', how='inner')

# %%
#Dropping NAS
#pd.dropna(inplace = True)
