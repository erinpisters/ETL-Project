# %%
#Import Dependencies
import pandas as pd
from sqlalchemy import create_engine 
import numpy as np

# %%
#Read in the Crime Excel File
crime_file = "Crime Rates by Metropolitan Areas 2016.xls"
crime_df = pd.read_excel(crime_file)
crime_df.head()
# Out:
#   Metropolitan Statistical Area; places in light type are parts of bigger metro areas, in bold.  \
# 0       San Juan-Carolina-Caguas, Puerto Rico M.S.A.
# 1                               Fairbanks, AK M.S.A.
# 2                  Detroit-Dearborn-Livonia, MI M.D.
# 3                    New Orleans-Metairie, LA M.S.A.
# 4                           Memphis, TN-MS-AR M.S.A.
#
#   Note that not all areas show Violent Crime Totals. Population  \
# 0                       Rate per 100,000 inhabitants    2157729
# 1                       Rate per 100,000 inhabitants      34657
# 2                       Rate per 100,000 inhabitants    1747582
# 3                       Rate per 100,000 inhabitants    1272995
# 4                       Rate per 100,000 inhabitants    1346931
#
#   Violent\ncrime  Murder and\nnonnegligent\nmanslaughter  Rape1  Robbery  \
# 0          245.3                                    23.4    4.9    123.0
# 1          669.4                                    20.2  101.0     92.3
# 2         1034.2                                    19.4   63.2    220.9
# 3          558.8                                    18.9   56.0    162.0
# 4         1082.1                                    18.5   54.6    269.4
#
#   Aggravated\nassault Property\ncrime  Burglary  Larceny-\ntheft  \
# 0                  94          1190.4     255.6            778.7
# 1               455.9          4377.2     499.2           3482.7
# 2               730.7          3132.6     735.0           1725.4
# 3               321.9          3001.3     468.3           2245.5
# 4               739.6          3868.2     934.3           2623.2
#
#    Motor\nvehicle\ntheft
# 0                  156.1
# 1                  395.3
# 2                  672.1
# 3                  287.5
# 4                  310.6

# %%
#Read in the Weather Excel File
weather_file = "cloudy_updated_new.csv"
weather_pd = pd.read_csv(weather_file)
weather_pd.head()
# Out:
#    Station        Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  PC_Feb  CD_Feb  \
# 0    13876  BIRMINGHAM ,AL   37      7       6      18      7       6      15
# 1     3856  HUNTSVILLE, AL   27      7       6      18      7       6      16
# 2    13894      MOBILE, AL   47      8       6      17      8       7      14
# 3    13895  MONTGOMERY, AL   51      7       6      17      8       6      14
# 4    26451   ANCHORAGE, AK   44      7       5      19      6       4      18
#
#   CL_Mar    ...      CD_Oct  CL_Nov PC_Nov  CD_Nov  CL_Dec PC_Dec  CD_Dec  \
# 0      7    ...           9      10      7      13       8      7      16
# 1      7    ...          12       9      7      14       8      6      18
# 2      9    ...           9      11      7      12       9      6      16
# 3      8    ...          10      11      6      13       9      6      16
# 4      8    ...          21       6      5      20       6      4      21
#
#    CL_Annual PC_Annual  CD_Annual
# 0         99       111        155
# 1        100       101        164
# 2        102       116        147
# 3        107       107        151
# 4         61        65        239
#
# [5 rows x 42 columns]

# %%
#Transform Crime Data Frame 
crime_cols = crime_df[["Metropolitan Statistical Area; places in light type are parts of bigger metro areas, in bold.","Aggravated\nassault", "Violent\ncrime","Murder and\nnonnegligent\nmanslaughter", "Robbery"]]
crime_cols.head()
# Out:
#   Metropolitan Statistical Area; places in light type are parts of bigger metro areas, in bold.  \
# 0       San Juan-Carolina-Caguas, Puerto Rico M.S.A.
# 1                               Fairbanks, AK M.S.A.
# 2                  Detroit-Dearborn-Livonia, MI M.D.
# 3                    New Orleans-Metairie, LA M.S.A.
# 4                           Memphis, TN-MS-AR M.S.A.
#
#   Aggravated\nassault Violent\ncrime  Murder and\nnonnegligent\nmanslaughter  \
# 0                  94          245.3                                    23.4
# 1               455.9          669.4                                    20.2
# 2               730.7         1034.2                                    19.4
# 3               321.9          558.8                                    18.9
# 4               739.6         1082.1                                    18.5
#
#    Robbery
# 0    123.0
# 1     92.3
# 2    220.9
# 3    162.0
# 4    269.4

# %%
#Rename the Columns
crime_clean = crime_cols.rename(columns={"Metropolitan Statistical Area; places in light type are parts of bigger metro areas, in bold.": "Location",
                                        "Aggravated\nassault": "Aggravated Assault",
                                        "Murder and\nnonnegligent\nmanslaughter": "Murder",
                                        "Violent\ncrime": "Violent Crime"})
crime_clean.head()
# Out:
#                                        Location Aggravated Assault  \
# 0  San Juan-Carolina-Caguas, Puerto Rico M.S.A.                 94
# 1                          Fairbanks, AK M.S.A.              455.9
# 2             Detroit-Dearborn-Livonia, MI M.D.              730.7
# 3               New Orleans-Metairie, LA M.S.A.              321.9
# 4                      Memphis, TN-MS-AR M.S.A.              739.6
#
#   Violent Crime  Murder  Robbery
# 0         245.3    23.4    123.0
# 1         669.4    20.2     92.3
# 2        1034.2    19.4    220.9
# 3         558.8    18.9    162.0
# 4        1082.1    18.5    269.4

# %%
#Drop empty data
crime_clean.dropna(inplace = True)
crime_clean=pd.concat([crime_clean,crime_clean.Location.str.split(',',expand=True)],1)

crime_clean.head()
# Out:
#                                        Location Aggravated Assault  \
# 0  San Juan-Carolina-Caguas, Puerto Rico M.S.A.                 94
# 1                          Fairbanks, AK M.S.A.              455.9
# 2             Detroit-Dearborn-Livonia, MI M.D.              730.7
# 3               New Orleans-Metairie, LA M.S.A.              321.9
# 4                      Memphis, TN-MS-AR M.S.A.              739.6
#
#   Violent Crime  Murder  Robbery                         0  \
# 0         245.3    23.4    123.0  San Juan-Carolina-Caguas
# 1         669.4    20.2     92.3                 Fairbanks
# 2        1034.2    19.4    220.9  Detroit-Dearborn-Livonia
# 3         558.8    18.9    162.0      New Orleans-Metairie
# 4        1082.1    18.5    269.4                   Memphis
#
#                      1     2
# 0   Puerto Rico M.S.A.  None
# 1            AK M.S.A.  None
# 2              MI M.D.  None
# 3            LA M.S.A.  None
# 4      TN-MS-AR M.S.A.  None

# %%
#Rename the new columns
crime_split = crime_clean.rename(columns={0: "City1",
                                        1: "State"})
crime_split.head()
# Out:
#                                        Location Aggravated Assault  \
# 0  San Juan-Carolina-Caguas, Puerto Rico M.S.A.                 94
# 1                          Fairbanks, AK M.S.A.              455.9
# 2             Detroit-Dearborn-Livonia, MI M.D.              730.7
# 3               New Orleans-Metairie, LA M.S.A.              321.9
# 4                      Memphis, TN-MS-AR M.S.A.              739.6
#
#   Violent Crime  Murder  Robbery                     City1  \
# 0         245.3    23.4    123.0  San Juan-Carolina-Caguas
# 1         669.4    20.2     92.3                 Fairbanks
# 2        1034.2    19.4    220.9  Detroit-Dearborn-Livonia
# 3         558.8    18.9    162.0      New Orleans-Metairie
# 4        1082.1    18.5    269.4                   Memphis
#
#                  State     2
# 0   Puerto Rico M.S.A.  None
# 1            AK M.S.A.  None
# 2              MI M.D.  None
# 3            LA M.S.A.  None
# 4      TN-MS-AR M.S.A.  None

# %%
#Drop the columns I dont need
crime_split = crime_split[["Location", "Aggravated Assault", "Violent Crime", "Murder", "Robbery", "City1", "State"]]
crime_split.head()
# Out:
#                                        Location Aggravated Assault  \
# 0  San Juan-Carolina-Caguas, Puerto Rico M.S.A.                 94
# 1                          Fairbanks, AK M.S.A.              455.9
# 2             Detroit-Dearborn-Livonia, MI M.D.              730.7
# 3               New Orleans-Metairie, LA M.S.A.              321.9
# 4                      Memphis, TN-MS-AR M.S.A.              739.6
#
#   Violent Crime  Murder  Robbery                     City1  \
# 0         245.3    23.4    123.0  San Juan-Carolina-Caguas
# 1         669.4    20.2     92.3                 Fairbanks
# 2        1034.2    19.4    220.9  Detroit-Dearborn-Livonia
# 3         558.8    18.9    162.0      New Orleans-Metairie
# 4        1082.1    18.5    269.4                   Memphis
#
#                  State
# 0   Puerto Rico M.S.A.
# 1            AK M.S.A.
# 2              MI M.D.
# 3            LA M.S.A.
# 4      TN-MS-AR M.S.A.

# %%
#Strip down the city names 
crime_split2=pd.concat([crime_split,crime_split.City1.str.split('-',expand=True)],1)
crime_split2.head()
# Out:
#                                        Location Aggravated Assault  \
# 0  San Juan-Carolina-Caguas, Puerto Rico M.S.A.                 94
# 1                          Fairbanks, AK M.S.A.              455.9
# 2             Detroit-Dearborn-Livonia, MI M.D.              730.7
# 3               New Orleans-Metairie, LA M.S.A.              321.9
# 4                      Memphis, TN-MS-AR M.S.A.              739.6
#
#   Violent Crime  Murder  Robbery                     City1  \
# 0         245.3    23.4    123.0  San Juan-Carolina-Caguas
# 1         669.4    20.2     92.3                 Fairbanks
# 2        1034.2    19.4    220.9  Detroit-Dearborn-Livonia
# 3         558.8    18.9    162.0      New Orleans-Metairie
# 4        1082.1    18.5    269.4                   Memphis
#
#                  State            0         1        2     3
# 0   Puerto Rico M.S.A.     San Juan  Carolina   Caguas  None
# 1            AK M.S.A.    Fairbanks      None     None  None
# 2              MI M.D.      Detroit  Dearborn  Livonia  None
# 3            LA M.S.A.  New Orleans  Metairie     None  None
# 4      TN-MS-AR M.S.A.      Memphis      None     None  None

# %%
#Clean up the final table (haha..what we thought was the final table)
crime_split2 = crime_split2.rename(columns={0: "City"})

crime_final2 = crime_split2[["State", "Aggravated Assault", "Violent Crime", "Murder", "Robbery", "City"]]

# %%
#Sorting the Cities by Alphabetical Order
crime_final3 = crime_final2.sort_values(by=['City'])

# %%
# Applying upper() method on 'City' column 
crime_final3['City'] = crime_final3['City'].str.upper()

# %%
# Finding the Rows that have Puerto Rico
crime_final3[crime_final3['State'].str.contains('Puerto')]
# Out:
#                  State Aggravated Assault Violent Crime  Murder  Robbery  \
# 0   Puerto Rico M.S.A.                 94         245.3    23.4    123.0
#
#        City
# 0  SAN JUAN

# %%
#Drop Puetro Rico
crime_final3.drop([0], inplace=True)

# %%
#Strip down the city names 
crime_final4=pd.concat([crime_final3,crime_final3.State.str.split(' ',expand=True)],1)
crime_final4.head()
# Out:
#            State Aggravated Assault Violent Crime  Murder  Robbery     City 0  \
# 94     TX M.S.A.              227.8         361.4     6.5     80.6  ABILENE
# 108   OH M.S.A.2                121         253.1     6.0     77.3    AKRON
# 367    OR M.S.A.                 59         113.9     0.0     27.0   ALBANY
# 282    NY M.S.A.                180         289.7     2.0     68.7   ALBANY
# 14     GA M.S.A.              534.9         734.8    11.8    159.9   ALBANY
#
#       1        2
# 94   TX   M.S.A.
# 108  OH  M.S.A.2
# 367  OR   M.S.A.
# 282  NY   M.S.A.
# 14   GA   M.S.A.

# %%
#Merging City and State
crime_final4['city_state'] = crime_final4['City'] + ', ' + crime_final4[1]

# %%
#Dropping the Extra States off of the end
crime_final4[crime_final4['city_state'].str.contains('-')]
# Out:
#                    State Aggravated Assault Violent Crime  Murder  Robbery  \
# 68          GA-SC M.S.A.              214.9         342.8     7.4     84.5
# 102         MO-IL M.S.A.                379         480.4     6.1     73.7
# 109         TN-GA M.S.A.              404.8         540.8     6.0     91.8
# 25      IL-IN-WI M.S.A.2              232.8           443    10.2    166.8
# 157      OH-KY-IN M.S.A.              109.2         257.3     4.7    102.3
# 88          TN-KY M.S.A.              309.7         427.6     6.7     70.9
# 23          GA-AL M.S.A.              279.2         518.3    10.4    189.9
# 103         MD-WV M.S.A.              213.7           318     6.1     72.9
# 218        IA-IL M.S.A.4              278.8         393.2     3.1     62.7
# 346         MN-WI M.S.A.              150.8         229.9     1.1     32.9
# 207         IN-KY M.S.A.              243.5         362.2     3.5     81.4
# 279         ND-MN M.S.A.                172         270.3     2.1     38.7
# 145         AR-OK M.S.A.                382         497.6     5.0     41.9
# 351         ND-MN M.S.A.              153.6         240.3     1.0     26.6
# 246         MD-WV M.S.A.              148.6         248.3     2.7     73.7
# 272     WV-KY-OH M.S.A.3              195.3         291.6     2.2     50.1
# 254         TN-VA M.S.A.              284.9         367.2     2.6     38.9
# 359         WI-MN M.S.A.               88.1         135.4     0.7     16.7
# 353           IL-WI M.D.              100.5         175.4     0.9     51.0
# 323         ID-WA M.S.A.              100.5         151.5     1.6      9.6
# 327         UT-ID M.S.A.               33.1          66.2     1.5      5.9
# 24          KY-IN M.S.A.              263.1         437.8    10.4    140.6
# 4        TN-MS-AR M.S.A.              739.6        1082.1    18.5    269.4
# 276        MN-WI M.S.A.2              147.5         287.7     2.2     94.9
# 75          SC-NC M.S.A.              304.9         460.7     7.2     77.7
# 217      NY-NJ-PA M.S.A.              210.9         354.9     3.3    121.2
# 222           NY-NJ M.D.              255.9         417.3     3.1    136.2
# 112           NJ-PA M.D.              126.5         283.6     6.0    134.2
# 192         NE-IA M.S.A.                227         351.2     3.9     78.2
# 57    PA-NJ-DE-MD M.S.A.              242.1         446.5     7.9    162.8
# 317         OR-WA M.S.A.              156.8         276.1     1.7     68.4
# 264        RI-MA M.S.A.3              208.2           315     2.4     65.7
# 196         MD-DE M.S.A.                273         404.5     3.8     88.5
# 309      IA-NE-SD M.S.A.              227.4         300.3     1.8     37.3
# 148        IN-MI M.S.A.2              249.6         463.2     5.0    153.9
# 58          MO-KS M.S.A.              278.1         420.2     7.9     86.9
# 69          TX-AR M.S.A.              324.3         447.4     7.4     58.2
# 31          VA-NC M.S.A.              200.6         352.1     9.5    104.7
# 169   DC-VA-MD-WV M.S.A.              157.8         301.3     4.5    108.3
# 125     DC-VA-MD-WV M.D.              174.4         331.3     5.3    120.4
# 320         WV-OH M.S.A.              100.5         159.2     1.7     36.0
# 243         WV-OH M.S.A.                275         349.8     2.8     30.1
# 72         DE-MD-NJ M.D.              315.9           513     7.3    163.4
# 136         VA-WV M.S.A.               64.1         138.7     5.2     19.4
#
#                             City 0            1        2  \
# 68                       AUGUSTA          GA-SC   M.S.A.
# 102               CAPE GIRARDEAU          MO-IL   M.S.A.
# 109                  CHATTANOOGA          TN-GA   M.S.A.
# 25                       CHICAGO       IL-IN-WI  M.S.A.2
# 157                   CINCINNATI       OH-KY-IN   M.S.A.
# 88                   CLARKSVILLE          TN-KY   M.S.A.
# 23                      COLUMBUS          GA-AL   M.S.A.
# 103                   CUMBERLAND          MD-WV   M.S.A.
# 218                    DAVENPORT          IA-IL  M.S.A.4
# 346                       DULUTH          MN-WI   M.S.A.
# 207                   EVANSVILLE          IN-KY   M.S.A.
# 279                        FARGO          ND-MN   M.S.A.
# 145                   FORT SMITH          AR-OK   M.S.A.
# 351                  GRAND FORKS          ND-MN   M.S.A.
# 246                   HAGERSTOWN          MD-WV   M.S.A.
# 272                   HUNTINGTON       WV-KY-OH  M.S.A.3
# 254                    KINGSPORT          TN-VA   M.S.A.
# 359                    LA CROSSE          WI-MN   M.S.A.
# 353                  LAKE COUNTY          IL-WI     M.D.
# 323                     LEWISTON          ID-WA   M.S.A.
# 327                        LOGAN          UT-ID   M.S.A.
# 24   LOUISVILLE/JEFFERSON COUNTY          KY-IN   M.S.A.
# 4                        MEMPHIS       TN-MS-AR   M.S.A.
# 276                  MINNEAPOLIS          MN-WI  M.S.A.2
# 75                  MYRTLE BEACH          SC-NC   M.S.A.
# 217                     NEW YORK       NY-NJ-PA   M.S.A.
# 222                     NEW YORK          NY-NJ     M.D.
# 112                       NEWARK          NJ-PA     M.D.
# 192                        OMAHA          NE-IA   M.S.A.
# 57                  PHILADELPHIA    PA-NJ-DE-MD   M.S.A.
# 317                     PORTLAND          OR-WA   M.S.A.
# 264                   PROVIDENCE          RI-MA  M.S.A.3
# 196                    SALISBURY          MD-DE   M.S.A.
# 309                   SIOUX CITY       IA-NE-SD   M.S.A.
# 148                   SOUTH BEND          IN-MI  M.S.A.2
# 58                    ST. JOSEPH          MO-KS   M.S.A.
# 69                     TEXARKANA          TX-AR   M.S.A.
# 31                VIRGINIA BEACH          VA-NC   M.S.A.
# 169                   WASHINGTON    DC-VA-MD-WV   M.S.A.
# 125                   WASHINGTON    DC-VA-MD-WV     M.D.
# 320                      WEIRTON          WV-OH   M.S.A.
# 243                     WHEELING          WV-OH   M.S.A.
# 72                    WILMINGTON       DE-MD-NJ     M.D.
# 136                   WINCHESTER          VA-WV   M.S.A.
#
#                              city_state
# 68                       AUGUSTA, GA-SC
# 102               CAPE GIRARDEAU, MO-IL
# 109                  CHATTANOOGA, TN-GA
# 25                    CHICAGO, IL-IN-WI
# 157                CINCINNATI, OH-KY-IN
# 88                   CLARKSVILLE, TN-KY
# 23                      COLUMBUS, GA-AL
# 103                   CUMBERLAND, MD-WV
# 218                    DAVENPORT, IA-IL
# 346                       DULUTH, MN-WI
# 207                   EVANSVILLE, IN-KY
# 279                        FARGO, ND-MN
# 145                   FORT SMITH, AR-OK
# 351                  GRAND FORKS, ND-MN
# 246                   HAGERSTOWN, MD-WV
# 272                HUNTINGTON, WV-KY-OH
# 254                    KINGSPORT, TN-VA
# 359                    LA CROSSE, WI-MN
# 353                  LAKE COUNTY, IL-WI
# 323                     LEWISTON, ID-WA
# 327                        LOGAN, UT-ID
# 24   LOUISVILLE/JEFFERSON COUNTY, KY-IN
# 4                     MEMPHIS, TN-MS-AR
# 276                  MINNEAPOLIS, MN-WI
# 75                  MYRTLE BEACH, SC-NC
# 217                  NEW YORK, NY-NJ-PA
# 222                     NEW YORK, NY-NJ
# 112                       NEWARK, NJ-PA
# 192                        OMAHA, NE-IA
# 57            PHILADELPHIA, PA-NJ-DE-MD
# 317                     PORTLAND, OR-WA
# 264                   PROVIDENCE, RI-MA
# 196                    SALISBURY, MD-DE
# 309                SIOUX CITY, IA-NE-SD
# 148                   SOUTH BEND, IN-MI
# 58                    ST. JOSEPH, MO-KS
# 69                     TEXARKANA, TX-AR
# 31                VIRGINIA BEACH, VA-NC
# 169             WASHINGTON, DC-VA-MD-WV
# 125             WASHINGTON, DC-VA-MD-WV
# 320                      WEIRTON, WV-OH
# 243                     WHEELING, WV-OH
# 72                 WILMINGTON, DE-MD-NJ
# 136                   WINCHESTER, VA-WV

# %%
crime_final4=crime_final4[["Aggravated Assault", "Violent Crime", "Murder", "Robbery", "city_state"]]

# %%
#Strip down the city names 
crime_final5=pd.concat([crime_final4,crime_final4.city_state.str.split('-',expand=True)],1)
crime_final5.head()
# Out:
#     Aggravated Assault Violent Crime  Murder  Robbery   city_state  \
# 94               227.8         361.4     6.5     80.6  ABILENE, TX
# 108                121         253.1     6.0     77.3    AKRON, OH
# 367                 59         113.9     0.0     27.0   ALBANY, OR
# 282                180         289.7     2.0     68.7   ALBANY, NY
# 14               534.9         734.8    11.8    159.9   ALBANY, GA
#
#                0     1     2     3
# 94   ABILENE, TX  None  None  None
# 108    AKRON, OH  None  None  None
# 367   ALBANY, OR  None  None  None
# 282   ALBANY, NY  None  None  None
# 14    ALBANY, GA  None  None  None

# %%
crime_final5=crime_final5[["Aggravated Assault", "Violent Crime", "Murder", "Robbery", 0]]
crime_final5.head()
# Out:
#     Aggravated Assault Violent Crime  Murder  Robbery            0
# 94               227.8         361.4     6.5     80.6  ABILENE, TX
# 108                121         253.1     6.0     77.3    AKRON, OH
# 367                 59         113.9     0.0     27.0   ALBANY, OR
# 282                180         289.7     2.0     68.7   ALBANY, NY
# 14               534.9         734.8    11.8    159.9   ALBANY, GA

# %%
#Rename the new columns FINAL CRIME DF
crime_final6 = crime_final5.rename(columns={0: "City_State"})
crime_final6.head()
# Out:
#     Aggravated Assault Violent Crime  Murder  Robbery   City_State
# 94               227.8         361.4     6.5     80.6  ABILENE, TX
# 108                121         253.1     6.0     77.3    AKRON, OH
# 367                 59         113.9     0.0     27.0   ALBANY, OR
# 282                180         289.7     2.0     68.7   ALBANY, NY
# 14               534.9         734.8    11.8    159.9   ALBANY, GA

# %%
# The start of the weather data
#Using concat to break apart "Location" into 2 columns and splitting by comma
weather_pd=pd.concat([weather_pd,weather_pd.Location.str.split(',',expand=True)],1)
weather_pd.head(360)
# Out:
#      Station                   Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  \
# 0      13876             BIRMINGHAM ,AL   37      7       6      18      7
# 1       3856             HUNTSVILLE, AL   27      7       6      18      7
# 2      13894                 MOBILE, AL   47      8       6      17      8
# 3      13895             MONTGOMERY, AL   51      7       6      17      8
# 4      26451              ANCHORAGE, AK   44      7       5      19      6
# 5      25308                ANNETTE, AK   41      4       4      23      3
# 6      27502                 BARROW, AK   54      6       2       3     12
# 7      26615                 BETHEL, AK   34      8       5      18     10
# 8      26533                 BETTLES,AK    5     15       5      11     10
# 9      26415               BIG DELTA,AK    3     14       8       9      5
# 10     25624                COLD BAY,AK   42      2       5      23      2
# 11     26411              FAIRBANKS, AK   45      9       6      16      8
# 12     26425                 GULKANA,AK    5     15       4      12      6
# 13     25507                  HOMER, AK   15      8       4      19      7
# 14     25309                 JUNEAU, AK   47      6       3      23      4
# 15     25503            KING SALMON, AK   42      8       5      18      7
# 16     25501                 KODIAK, AK   25      5       6      20      6
# 17     26616               KOTZEBUE, AK   52     11       4      16     12
# 18     26510                MCGRATH, AK   55      9       5      17      9
# 19     26617                   NOME, AK   51     10       4      17     12
# 20     25713        ST. PAUL ISLAND, AK   66      2       6      23      3
# 21     26528              TALKEETNA, AK   10      6       4      21      8
# 22     26627             UNALAKLEET, AK    4      8       4      20     10
# 23     26442                 VALDEZ, AK   26      5       4      21      5
# 24     25339                YAKUTAT, AK   48      5       3      22      4
# 25      3103              FLAGSTAFF, AZ   43     12       6      12     11
# 26     23183                PHOENIX, AZ   57     14       7      10     13
# 27     23160                 TUCSON, AZ   55     14       7      10     13
# 28     23194                WINSLOW, AZ   37     12       7      12     12
# 29     23195                   YUMA, AZ   32     15       7       9     15
# ..       ...                        ...  ...    ...     ...     ...    ...
# 240    13741                ROANOKE, VA   48      8       8      15      8
# 241    24227                OLYMPIA, WA   54      2       4      25      2
# 242    94240             QUILLAYUTE, WA   29      3       3      24      4
# 243    24281           SEATTLE C.O., WA   24      3       5      23      3
# 244    24233     SEATTLE SEA-TAC AP, WA   51      3       4      24      3
# 245    24157                SPOKANE, WA   48      3       4      24      3
# 246    24243                 YAKIMA, WA   49      4       5      22      4
# 247     3872                BECKLEY, WV   32      5       5      21      4
# 248    13866             CHARLESTON, WV   47      4       6      21      4
# 249    13729                 ELKINS, WV   49      3       6      22      3
# 250     3860             HUNTINGTON, WV   34      4       6      21      4
# 251    14898              GREEN BAY, WI   46      8       7      17      7
# 252    14920              LA CROSSE, WI   17      7       7      17      8
# 253    14837                MADISON, WI   49      7       6      17      7
# 254    14839              MILWAUKEE, WI   55      7       6      18      6
# 255    24089                 CASPER, WY   45      7       8      16      6
# 256    24018               CHEYENNE, WY   60      9      10      13      7
# 257    24021                 LANDER, WY   49      8      10      13      7
# 258    24029               SHERIDAN, WY   55      6       8      17      5
# 259    41415                   GUAM, PC   20      3      13      15      2
# 260    21603        JOHNSTON ISLAND, PC   24     13      14       4     11
# 261    40309                  KOROR, PC   53      *       7      23      *
# 262    40604   KWAJALEIN- MARSHALL IS.,   56      2       7      21      2
# 263    40710    MAJURO- MARSHALL IS, PC   49      1       7      23      1
# 264    61705  PAGO PAGO- AMER SAMOA, PC   39      0      10      21      0
# 265    40504  POHNPEI- CAROLINE IS., PC   53      *       4      26      *
# 266    40505  CHUUK- E. CAROLINE IS., P   56      *       4      27      *
# 267    41606            WAKE ISLAND, PC   43     12      13       5     12
# 268    40308    YAP- W CAROLINE IS., PC   56      1       8      22      0
# 269    11641               SAN JUAN, PR   40      9      18       4      7
#
#      PC_Feb  CD_Feb CL_Mar ...   PC_Nov  CD_Nov CL_Dec  PC_Dec  CD_Dec  \
# 0         6      15      7 ...        7      13      8       7      16
# 1         6      16      7 ...        7      14      8       6      18
# 2         7      14      9 ...        7      12      9       6      16
# 3         6      14      8 ...        6      13      9       6      16
# 4         4      18      8 ...        5      20      6       4      21
# 5         4      21      4 ...        3      24      3       4      24
# 6         6      11     14 ...        3      11      4       0       0
# 7         4      14      9 ...        5      19      8       5      18
# 8         4      14      9 ...        6      14      9       7      15
# 9         7      17      8 ...        6      17      7       7      17
# 10        5      22      2 ...        6      23      2       5      24
# 11        6      14     10 ...        5      18      7       6      18
# 12        4      18      9 ...        5      21      7       7      17
# 13        4      17      6 ...        5      19      7       5      18
# 14        3      21      4 ...        2      24      3       2      25
# 15        5      16      8 ...        5      19      7       6      19
# 16        5      18      6 ...        7      16      6       6      19
# 17        3      13     12 ...        4      17     11       4      16
# 18        4      15      9 ...        4      19      8       5      19
# 19        4      13     11 ...        4      18     10       4      17
# 20        6      20      3 ...        6      22      1       5      24
# 21        4      16      9 ...        3      19      5       2      22
# 22        3      15     10 ...        5      18     11       4      16
# 23        3      20      8 ...        4      20      5       3      23
# 24        3      21      5 ...        3      23      4       3      24
# 25        6      11     12 ...        7       8     14       6      11
# 26        7       9     14 ...        6       6     15       6       9
# 27        7       9     15 ...        6       6     15       6      10
# 28        7      10     13 ...        6       8     14       7      10
# 29        7       6     17 ...        6       5     17       7       8
# ..      ...     ...    ... ...      ...     ...    ...     ...     ...
# 240       7      14      8 ...        8      13      9       8      14
# 241       4      22      3 ...        5      23      2       4      26
# 242       4      21      4 ...        5      22      4       4      24
# 243       6      19      4 ...        6      21      3       5      23
# 244       4      21      3 ...        4      23      2       4      25
# 245       5      20      5 ...        5      22      3       4      24
# 246       6      18      6 ...        6      19      4       5      22
# 247       5      18      5 ...        7      18      5       6      21
# 248       6      18      5 ...        7      18      5       6      20
# 249       6      19      4 ...        6      19      4       5      21
# 250       5      19      5 ...        6      19      5       5      21
# 251       7      15      7 ...        6      19      6       6      19
# 252       7      13      7 ...        6      18      7       6      18
# 253       6      15      6 ...        6      18      6       6      19
# 254       6      15      6 ...        6      18      6       6      19
# 255       8      14      6 ...        8      14      8       8      15
# 256       9      12      7 ...        9      11      9       9      13
# 257      10      12      7 ...       10      12     10      10      12
# 258       8      15      5 ...        8      16      7       8      17
# 259      10      16      3 ...       13      15      3      12      16
# 260      13       4     11 ...       12      12     11      13       7
# 261       7      21      1 ...        8      22      *       7      24
# 262       6      20      2 ...        6      23      2       6      23
# 263       8      19      1 ...        7      23      1       6      24
# 264       9      18      1 ...       11      18      1      10      20
# 265       4      24      * ...        6      24      *       5      26
# 266       3      25      * ...        4      26      *       3      28
# 267      11       5     12 ...       13       5     14      13       4
# 268       8      20      1 ...        8      21      0       9      22
# 269      16       4      9 ...       18       7      7      18       6
#
#     CL_Annual  PC_Annual  CD_Annual                        0    1
# 0          99        111        155              BIRMINGHAM    AL
# 1         100        101        164               HUNTSVILLE   AL
# 2         102        116        147                   MOBILE   AL
# 3         107        107        151               MONTGOMERY   AL
# 4          61         65        239                ANCHORAGE   AK
# 5          40         60        265                  ANNETTE   AK
# 6          66         52        187                   BARROW   AK
# 7          62         65        239                   BETHEL   AK
# 8          86         93        187                  BETTLES   AK
# 9          60         93        212                BIG DELTA   AK
# 10         10         50        304                 COLD BAY   AK
# 11         70         86        210                FAIRBANKS   AK
# 12         67         89        209                  GULKANA   AK
# 13         65         75        225                    HOMER   AK
# 14         44         41        280                   JUNEAU   AK
# 15         51         69        245              KING SALMON   AK
# 16         59         74        232                   KODIAK   AK
# 17        100         72        193                 KOTZEBUE   AK
# 18         67         72        226                  MCGRATH   AK
# 19         91         69        205                     NOME   AK
# 20         18         61        287          ST. PAUL ISLAND   AK
# 21         67         67        225                TALKEETNA   AK
# 22         83         67        215               UNALAKLEET   AK
# 23         57         57        251                   VALDEZ   AK
# 24         41         46        278                  YAKUTAT   AK
# 25        162        102        102                FLAGSTAFF   AZ
# 26        211         85         70                  PHOENIX   AZ
# 27        193         91         81                   TUCSON   AZ
# 28        177         99         89                  WINSLOW   AZ
# 29        242         71         52                     YUMA   AZ
# ..        ...        ...        ...                      ...  ...
# 240       102        112        151                  ROANOKE   VA
# 241        52         84        228                  OLYMPIA   WA
# 242        51         75        239               QUILLAYUTE   WA
# 243        71         93        201             SEATTLE C.O.   WA
# 244        58         82        226       SEATTLE SEA-TAC AP   WA
# 245        86         88        191                  SPOKANE   WA
# 246       109         92        164                   YAKIMA   WA
# 247        60         95        210                  BECKLEY   WV
# 248        65        111        189               CHARLESTON   WV
# 249        48        103        212                   ELKINS   WV
# 250        63         99        203               HUNTINGTON   WV
# 251        85        102        178                GREEN BAY   WI
# 252        95         97        173                LA CROSSE   WI
# 253        89         96        180                  MADISON   WI
# 254        90        100        175                MILWAUKEE   WI
# 255       107        111        147                   CASPER   WY
# 256       106        127        133                 CHEYENNE   WY
# 257       114        122        129                   LANDER   WY
# 258        95        113        157                 SHERIDAN   WY
# 259        16        134        215                     GUAM   PC
# 260        99        159        107          JOHNSTON ISLAND   PC
# 261         4         86        273                    KOROR   PC
# 262        17         76        272  KWAJALEIN- MARSHALL IS.
# 263         7         86        271      MAJURO- MARSHALL IS   PC
# 264        12        151        202    PAGO PAGO- AMER SAMOA   PC
# 265         2         64        298    POHNPEI- CAROLINE IS.   PC
# 266         0         45        318   CHUUK- E. CAROLINE IS.    P
# 267       121        149         94              WAKE ISLAND   PC
# 268         5         90        270      YAP- W CAROLINE IS.   PC
# 269        73        203         89                 SAN JUAN   PR
#
# [270 rows x 44 columns]

# %%
#Renaming new columns
weather_pd = weather_pd.rename(columns={0: "City", 1: "State"})
weather_pd.head()
# Out:
#    Station        Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  PC_Feb  CD_Feb  \
# 0    13876  BIRMINGHAM ,AL   37      7       6      18      7       6      15
# 1     3856  HUNTSVILLE, AL   27      7       6      18      7       6      16
# 2    13894      MOBILE, AL   47      8       6      17      8       7      14
# 3    13895  MONTGOMERY, AL   51      7       6      17      8       6      14
# 4    26451   ANCHORAGE, AK   44      7       5      19      6       4      18
#
#   CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  CD_Dec CL_Annual  PC_Annual  \
# 0      7  ...         7      13      8       7      16        99        111
# 1      7  ...         7      14      8       6      18       100        101
# 2      9  ...         7      12      9       6      16       102        116
# 3      8  ...         6      13      9       6      16       107        107
# 4      8  ...         5      20      6       4      21        61         65
#
#    CD_Annual         City  State
# 0        155  BIRMINGHAM      AL
# 1        164   HUNTSVILLE     AL
# 2        147       MOBILE     AL
# 3        151   MONTGOMERY     AL
# 4        239    ANCHORAGE     AK
#
# [5 rows x 44 columns]

# %%
#Checking to see unique values in each column
#weather_pd.CL_Jan.unique()

# %%
# Checking the names of all of the columns
weather_pd.columns
# Out:
# Index(['Station', 'Location', 'Year', 'CL_Jan', 'PC_Jan', 'CD_Jan', 'CL_Feb',
#        'PC_Feb', 'CD_Feb', 'CL_Mar', 'PC_Mar', 'CD_Mar', 'CL_Apr', 'PC_Apr',
#        'CD_Apr', 'CL_May', 'PC_May', 'CD_May', 'CL_Jun', 'PC_Jun', 'CD_Jun',
#        'CL_Jul', 'PC_Jul', 'CD_Jul', 'CL_Aug', 'PC_Aug', 'CD_Aug', 'CL_Sep',
#        'PC_Sep', 'CD_Sep', 'CL_Oct', 'PC_Oct', 'CD_Oct', 'CL_Nov', 'PC_Nov',
#        'CD_Nov', 'CL_Dec', 'PC_Dec', 'CD_Dec', 'CL_Annual', 'PC_Annual',
#        'CD_Annual', 'City', 'State'],
#       dtype='object')

# %%
# Checking to see if every column has the same amount of entries
weather_pd.count()
# Out:
# Station      270
# Location     270
# Year         270
# CL_Jan       270
# PC_Jan       270
# CD_Jan       270
# CL_Feb       270
# PC_Feb       270
# CD_Feb       270
# CL_Mar       270
# PC_Mar       270
# CD_Mar       270
# CL_Apr       270
# PC_Apr       270
# CD_Apr       270
# CL_May       270
# PC_May       270
# CD_May       270
# CL_Jun       270
# PC_Jun       270
# CD_Jun       270
# CL_Jul       270
# PC_Jul       270
# CD_Jul       270
# CL_Aug       270
# PC_Aug       270
# CD_Aug       270
# CL_Sep       270
# PC_Sep       270
# CD_Sep       270
# CL_Oct       270
# PC_Oct       270
# CD_Oct       270
# CL_Nov       270
# PC_Nov       270
# CD_Nov       270
# CL_Dec       270
# PC_Dec       270
# CD_Dec       270
# CL_Annual    270
# PC_Annual    270
# CD_Annual    270
# City         270
# State        270
# dtype: int64

# %%
#Checking to see the column types
weather_pd.dtypes
# Out:
# Station       int64
# Location     object
# Year         object
# CL_Jan       object
# PC_Jan        int64
# CD_Jan        int64
# CL_Feb       object
# PC_Feb        int64
# CD_Feb        int64
# CL_Mar       object
# PC_Mar        int64
# CD_Mar        int64
# CL_Apr       object
# PC_Apr        int64
# CD_Apr        int64
# CL_May       object
# PC_May        int64
# CD_May        int64
# CL_Jun       object
# PC_Jun        int64
# CD_Jun        int64
# CL_Jul       object
# PC_Jul        int64
# CD_Jul        int64
# CL_Aug       object
# PC_Aug        int64
# CD_Aug        int64
# CL_Sep       object
# PC_Sep        int64
# CD_Sep        int64
# CL_Oct       object
# PC_Oct        int64
# CD_Oct        int64
# CL_Nov       object
# PC_Nov        int64
# CD_Nov        int64
# CL_Dec       object
# PC_Dec        int64
# CD_Dec        int64
# CL_Annual     int64
# PC_Annual     int64
# CD_Annual     int64
# City         object
# State        object
# dtype: object

# %%
#Checking to see unique values in each column
weather_pd.CL_Jan.unique()
# Out:
# array(['7', '8', '4', '6', '15', '14', '2', '9', '5', '11', '10', '12',
#        '13', '3', '1', '*', '0'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Feb.unique()
# Out:
# array(['7', '8', '6', '3', '12', '10', '5', '2', '4', '9', '11', '13',
#        '15', '14', '*', '1', '0'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Mar.unique()
# Out:
# array(['7', '9', '8', '4', '14', '2', '10', '6', '12', '11', '3', '5',
#        '15', '13', '17', '1', '*'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Apr.unique()
# Out:
# array(['9', '10', '6', '3', '11', '7', '2', '1', '5', '4', '12', '17',
#        '15', '21', '14', '8', '13', '16', '*'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_May.unique()
# Out:
# array(['8', '9', '4', '3', '7', '2', '*', '5', '1', '6', '15', '21', '20',
#        '17', '24', '18', '12', '10', '11', '14', '13', '19'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Jun.unique()
# Out:
# array(['7', '8', '3', '2', '4', '*', '1', '6', '5', '18', '23', '21',
#        '20', '25', '10', '9', '12', '14', '16', '17', '22', '15', '11',
#        '13'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Jul.unique()
# Out:
# array(['5', '7', '4', '6', '3', '2', '*', '1', '9', '17', '10', '11',
#        '20', '12', '26', '22', '27', '18', '13', '21', '25', '14', '8',
#        '15', '19', '16', '23', '0'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Aug.unique()
# Out:
# array(['7', '9', '6', '8', '3', '4', '1', '2', '*', '5', '10', '18', '12',
#        '22', '26', '23', '25', '19', '14', '24', '15', '17', '11', '13',
#        '16', '20', '21', '0'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Sep.unique()
# Out:
# array(['9', '10', '4', '1', '2', '7', '5', '*', '6', '3', '16', '22',
#        '19', '18', '24', '12', '11', '23', '15', '13', '21', '14', '8',
#        '17'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Oct.unique()
# Out:
# array(['14', '12', '5', '2', '4', '1', '3', '6', '8', '7', '17', '20',
#        '19', '23', '13', '16', '18', '15', '11', '9', '10', '*', '0'],
#       dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Nov.unique()
# Out:
# array(['10', '9', '11', '6', '3', '7', '1', '5', '4', '8', '15', '18',
#        '16', '19', '12', '13', '14', '2', '*', '0'], dtype=object)

# %%
#Checking to see unique values in each column
weather_pd.CL_Nov.unique()
# Out:
# array(['10', '9', '11', '6', '3', '7', '1', '5', '4', '8', '15', '18',
#        '16', '19', '12', '13', '14', '2', '*', '0'], dtype=object)

# %%
# Checking to see what rows have * instead of numbers
weather_pd.loc[weather_pd["CL_Jan"]=="*"]
weather_pd.loc[weather_pd["CL_Feb"]=="*"]
weather_pd.loc[weather_pd["CL_Mar"]=="*"]
weather_pd.loc[weather_pd["CL_Apr"]=="*"]
weather_pd.loc[weather_pd["CL_May"]=="*"]
weather_pd.loc[weather_pd["CL_Jun"]=="*"]
weather_pd.loc[weather_pd["CL_Jul"]=="*"]
weather_pd.loc[weather_pd["CL_Aug"]=="*"]
weather_pd.loc[weather_pd["CL_Sep"]=="*"]
weather_pd.loc[weather_pd["CL_Oct"]=="*"]
weather_pd.loc[weather_pd["CL_Nov"]=="*"]
weather_pd.loc[weather_pd["CL_Dec"]=="*"]
# Out:
#      Station                   Location Year CL_Jan  PC_Jan  CD_Jan CL_Feb  \
# 261    40309                  KOROR, PC   53      *       7      23      *
# 265    40504  POHNPEI- CAROLINE IS., PC   53      *       4      26      *
# 266    40505  CHUUK- E. CAROLINE IS., P   56      *       4      27      *
#
#      PC_Feb  CD_Feb CL_Mar  ...    PC_Nov  CD_Nov CL_Dec  PC_Dec  CD_Dec  \
# 261       7      21      1  ...         8      22      *       7      24
# 265       4      24      *  ...         6      24      *       5      26
# 266       3      25      *  ...         4      26      *       3      28
#
#     CL_Annual  PC_Annual  CD_Annual                    City  State
# 261         4         86        273                   KOROR     PC
# 265         2         64        298   POHNPEI- CAROLINE IS.     PC
# 266         0         45        318  CHUUK- E. CAROLINE IS.      P
#
# [3 rows x 44 columns]

# %%
# Dropping the rows that contain asteric
weather_pd.drop([9,10,258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269], inplace=True)

# %%
weather_pd["CL_Annual_Check"] = pd.to_numeric(weather_pd["CL_Jan"]) + pd.to_numeric(weather_pd["CL_Feb"]) + pd.to_numeric(weather_pd["CL_Mar"]) + pd.to_numeric(weather_pd["CL_Apr"]) + pd.to_numeric(weather_pd["CL_May"]) + pd.to_numeric(weather_pd["CL_Jun"]) + pd.to_numeric(weather_pd["CL_Jul"]) + pd.to_numeric(weather_pd["CL_Aug"]) + pd.to_numeric(weather_pd["CL_Sep"]) + pd.to_numeric(weather_pd["CL_Oct"]) + pd.to_numeric(weather_pd["CL_Nov"]) + pd.to_numeric(weather_pd["CL_Dec"])

# %%
#Checking to see whether two columns are equal - since theyre not equal, will go ahead and use CL_annual number
weather_pd['CL_Annual_Check'].equals(weather_pd['CL_Annual'])
# Out:
# False

# %%
#Only using columns that we need
weather_updated = weather_pd[["City", "State","CL_Annual"]]

# %%
weather_updated2 = weather_updated.sort_values(by=['City'])

# %%
weather_updated2['City_State'] = weather_updated2['City'] + ',' + weather_updated2['State']
weather_updated2.head()
# Out:
#          City State  CL_Annual    City_State
# 207  ABERDEEN    SD        101  ABERDEEN, SD
# 217   ABILENE    TX        149   ABILENE, TX
# 176     AKRON    OH         68     AKRON, OH
# 47    ALAMOSA    CO        148   ALAMOSA, CO
# 159    ALBANY    NY         69    ALBANY, NY

# %%
#Only using columns that we need
weather_final = weather_updated2[["City_State","CL_Annual"]]

# %%
merge_table_final = pd.merge(crime_final6, weather_final, on="City_State", how="inner")
merge_table_final
# Out:
#     Aggravated Assault Violent Crime  Murder  Robbery            City_State  \
# 0                227.8         361.4     6.5     80.6           ABILENE, TX
# 1                  121         253.1     6.0     77.3             AKRON, OH
# 2                  180         289.7     2.0     68.7            ALBANY, NY
# 3                596.7           901     8.3    238.7       ALBUQUERQUE, NM
# 4                413.7         592.7     5.3    102.2          AMARILLO, TX
# 5                707.8        1114.9     8.9    224.6         ANCHORAGE, AK
# 6                158.9         240.4     5.1     54.7         ASHEVILLE, NC
# 7                214.6         341.5     2.9     85.9            ATHENS, GA
# 8                228.2         403.2     6.8    144.1           ATLANTA, GA
# 9                187.4         316.9     3.4     68.7            AUSTIN, TX
# 10               403.3         579.8     9.9    131.8       BAKERSFIELD, CA
# 11               386.9         710.3    14.1    276.7         BALTIMORE, MD
# 12               321.9           505     9.5    140.1       BATON ROUGE, LA
# 13                 329         417.2     9.9     48.6           BECKLEY, WV
# 14               274.9         377.1     1.8     54.0          BILLINGS, MT
# 15                 164         289.3     2.5     60.0        BINGHAMTON, NY
# 16                 217         293.5     2.3     26.3          BISMARCK, ND
# 17                 124         229.8     1.5     85.6        BRIDGEPORT, CT
# 18                 277         379.1     1.9     52.8       BROWNSVILLE, TX
# 19               234.2           411     4.9    138.9           BUFFALO, NY
# 20               160.5         202.7     0.0     14.5            CASPER, WY
# 21               466.9           615     7.8     96.3        CHARLESTON, WV
# 22               404.8         540.8     6.0     91.8       CHATTANOOGA, TN
# 23               188.1         251.9     8.2     18.5          CHEYENNE, WY
# 24               197.4         445.5     9.2    195.1         CLEVELAND, OH
# 25               250.5         404.6     4.5     68.3  COLORADO SPRINGS, CO
# 26               224.6         380.4     3.4     77.9          COLUMBIA, MO
# 27               430.2         589.5     7.1    103.5          COLUMBIA, SC
# 28                94.9         284.9     5.2    125.1          COLUMBUS, OH
# 29               279.2         518.3    10.4    189.9          COLUMBUS, GA
# ..                 ...           ...     ...      ...                   ...
# 107              233.2         410.5     3.9    103.9    SALT LAKE CITY, UT
# 108                216         333.5     5.0     48.0        SAN ANGELO, TX
# 109                348         526.4     7.7    104.9       SAN ANTONIO, TX
# 110              210.8         330.4     3.0     83.7         SAN DIEGO, CA
# 111              211.9         342.4     2.9     72.9       SANTA MARIA, CA
# 112              227.4         417.4    13.8    155.8          SAVANNAH, GA
# 113              451.7         650.9    11.7    140.7        SHREVEPORT, LA
# 114              227.4         300.3     1.8     37.3        SIOUX CITY, IA
# 115                276         388.1     3.9     48.4       SIOUX FALLS, SD
# 116              249.6         463.2     5.0    153.9        SOUTH BEND, IN
# 117                200         335.6     2.9     74.2           SPOKANE, WA
# 118                419         603.6     2.6    100.3       SPRINGFIELD, MO
# 119              533.6         740.1     3.8    132.7       SPRINGFIELD, IL
# 120              562.2         823.6     8.5    222.7          STOCKTON, CA
# 121              154.2         276.4     5.3     65.6          SYRACUSE, NY
# 122                425         631.6     4.5    127.5       TALLAHASSEE, FL
# 123              228.7         340.8     3.9     75.6             TAMPA, FL
# 124              388.8         616.8     7.1    149.2            TOLEDO, OH
# 125              240.9         391.5     9.0    108.8            TOPEKA, KS
# 126              293.4         496.4     4.8    141.0            TUCSON, AZ
# 127              385.3         588.9     9.2    126.4             TULSA, OK
# 128              271.3         424.1     2.7     71.6              WACO, TX
# 129              344.7         442.4     1.8     42.1          WATERLOO, IA
# 130              290.1         451.9     5.3    121.2   WEST PALM BEACH, FL
# 131              535.9         708.8     6.5    106.3           WICHITA, KS
# 132              178.5         362.3     8.0     85.9     WICHITA FALLS, TX
# 133              121.9         205.7     6.1     50.1      WILLIAMSPORT, PA
# 134              233.1         363.6     6.0     95.5        WILMINGTON, NC
# 135              315.9           513     7.3    163.4        WILMINGTON, DE
# 136              183.9         299.5     8.4     74.6            YAKIMA, WA
#
#      CL_Annual
# 0          149
# 1           68
# 2           69
# 3          167
# 4          157
# 5           61
# 6           99
# 7          113
# 8          110
# 9          115
# 10         191
# 11         105
# 12          99
# 13          60
# 14          89
# 15          52
# 16          93
# 17          99
# 18          96
# 19          54
# 20         107
# 21          65
# 22         104
# 23         106
# 24          66
# 25         127
# 26         104
# 27         115
# 28          72
# 29         110
# ..         ...
# 107        125
# 108        154
# 109        105
# 110        146
# 111        176
# 112        104
# 113        114
# 114        104
# 115        105
# 116         73
# 117         86
# 118        115
# 119        104
# 120        184
# 121         63
# 122        102
# 123        101
# 124         73
# 125        114
# 126        193
# 127        127
# 128        130
# 129         91
# 130         75
# 131        128
# 132        151
# 133         67
# 134        111
# 135         97
# 136        109
#
# [137 rows x 6 columns]

# %%
merge_table_final.count()
# Out:
# Aggravated Assault    137
# Violent Crime         137
# Murder                137
# Robbery               137
# City_State            137
# CL_Annual             137
# dtype: int64

# %%
merge_table_final.head(137)
# Out:
#     Aggravated Assault Violent Crime  Murder  Robbery            City_State  \
# 0                227.8         361.4     6.5     80.6           ABILENE, TX
# 1                  121         253.1     6.0     77.3             AKRON, OH
# 2                  180         289.7     2.0     68.7            ALBANY, NY
# 3                596.7           901     8.3    238.7       ALBUQUERQUE, NM
# 4                413.7         592.7     5.3    102.2          AMARILLO, TX
# 5                707.8        1114.9     8.9    224.6         ANCHORAGE, AK
# 6                158.9         240.4     5.1     54.7         ASHEVILLE, NC
# 7                214.6         341.5     2.9     85.9            ATHENS, GA
# 8                228.2         403.2     6.8    144.1           ATLANTA, GA
# 9                187.4         316.9     3.4     68.7            AUSTIN, TX
# 10               403.3         579.8     9.9    131.8       BAKERSFIELD, CA
# 11               386.9         710.3    14.1    276.7         BALTIMORE, MD
# 12               321.9           505     9.5    140.1       BATON ROUGE, LA
# 13                 329         417.2     9.9     48.6           BECKLEY, WV
# 14               274.9         377.1     1.8     54.0          BILLINGS, MT
# 15                 164         289.3     2.5     60.0        BINGHAMTON, NY
# 16                 217         293.5     2.3     26.3          BISMARCK, ND
# 17                 124         229.8     1.5     85.6        BRIDGEPORT, CT
# 18                 277         379.1     1.9     52.8       BROWNSVILLE, TX
# 19               234.2           411     4.9    138.9           BUFFALO, NY
# 20               160.5         202.7     0.0     14.5            CASPER, WY
# 21               466.9           615     7.8     96.3        CHARLESTON, WV
# 22               404.8         540.8     6.0     91.8       CHATTANOOGA, TN
# 23               188.1         251.9     8.2     18.5          CHEYENNE, WY
# 24               197.4         445.5     9.2    195.1         CLEVELAND, OH
# 25               250.5         404.6     4.5     68.3  COLORADO SPRINGS, CO
# 26               224.6         380.4     3.4     77.9          COLUMBIA, MO
# 27               430.2         589.5     7.1    103.5          COLUMBIA, SC
# 28                94.9         284.9     5.2    125.1          COLUMBUS, OH
# 29               279.2         518.3    10.4    189.9          COLUMBUS, GA
# ..                 ...           ...     ...      ...                   ...
# 107              233.2         410.5     3.9    103.9    SALT LAKE CITY, UT
# 108                216         333.5     5.0     48.0        SAN ANGELO, TX
# 109                348         526.4     7.7    104.9       SAN ANTONIO, TX
# 110              210.8         330.4     3.0     83.7         SAN DIEGO, CA
# 111              211.9         342.4     2.9     72.9       SANTA MARIA, CA
# 112              227.4         417.4    13.8    155.8          SAVANNAH, GA
# 113              451.7         650.9    11.7    140.7        SHREVEPORT, LA
# 114              227.4         300.3     1.8     37.3        SIOUX CITY, IA
# 115                276         388.1     3.9     48.4       SIOUX FALLS, SD
# 116              249.6         463.2     5.0    153.9        SOUTH BEND, IN
# 117                200         335.6     2.9     74.2           SPOKANE, WA
# 118                419         603.6     2.6    100.3       SPRINGFIELD, MO
# 119              533.6         740.1     3.8    132.7       SPRINGFIELD, IL
# 120              562.2         823.6     8.5    222.7          STOCKTON, CA
# 121              154.2         276.4     5.3     65.6          SYRACUSE, NY
# 122                425         631.6     4.5    127.5       TALLAHASSEE, FL
# 123              228.7         340.8     3.9     75.6             TAMPA, FL
# 124              388.8         616.8     7.1    149.2            TOLEDO, OH
# 125              240.9         391.5     9.0    108.8            TOPEKA, KS
# 126              293.4         496.4     4.8    141.0            TUCSON, AZ
# 127              385.3         588.9     9.2    126.4             TULSA, OK
# 128              271.3         424.1     2.7     71.6              WACO, TX
# 129              344.7         442.4     1.8     42.1          WATERLOO, IA
# 130              290.1         451.9     5.3    121.2   WEST PALM BEACH, FL
# 131              535.9         708.8     6.5    106.3           WICHITA, KS
# 132              178.5         362.3     8.0     85.9     WICHITA FALLS, TX
# 133              121.9         205.7     6.1     50.1      WILLIAMSPORT, PA
# 134              233.1         363.6     6.0     95.5        WILMINGTON, NC
# 135              315.9           513     7.3    163.4        WILMINGTON, DE
# 136              183.9         299.5     8.4     74.6            YAKIMA, WA
#
#      CL_Annual
# 0          149
# 1           68
# 2           69
# 3          167
# 4          157
# 5           61
# 6           99
# 7          113
# 8          110
# 9          115
# 10         191
# 11         105
# 12          99
# 13          60
# 14          89
# 15          52
# 16          93
# 17          99
# 18          96
# 19          54
# 20         107
# 21          65
# 22         104
# 23         106
# 24          66
# 25         127
# 26         104
# 27         115
# 28          72
# 29         110
# ..         ...
# 107        125
# 108        154
# 109        105
# 110        146
# 111        176
# 112        104
# 113        114
# 114        104
# 115        105
# 116         73
# 117         86
# 118        115
# 119        104
# 120        184
# 121         63
# 122        102
# 123        101
# 124         73
# 125        114
# 126        193
# 127        127
# 128        130
# 129         91
# 130         75
# 131        128
# 132        151
# 133         67
# 134        111
# 135         97
# 136        109
#
# [137 rows x 6 columns]

# %%
merge_table_final.dropna(inplace = True)

# %%
merge_table_final.count()
# Out:
# Aggravated Assault    137
# Violent Crime         137
# Murder                137
# Robbery               137
# City_State            137
# CL_Annual             137
# dtype: int64

# %%
connection_string = "root:<abcdefg12345>@3306/weathercrime_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
# Confirm table
engine.table_names()

# %%
merge_table_final.to_sql(name='wcjoin', con=engine, if_exists='append', index=True)
